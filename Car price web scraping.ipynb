# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\user\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.0.4)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = "https://www.cars.com/shopping/results/?stock_type=all&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance=20&zip="

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">New and used Mercedes-Benz for Sale Near Me | Cars.com</title>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Mercedes-Benz models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="New and used Mercedes-Benz for Sale Near Me | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results/" property="og:url"/>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Mercedes-Benz models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="New and used Mercedes-Benz for Sale Near Me | Cars.com" name="twitter:title"/>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Mercedes-Benz models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{margin:0;padding:0;border:0;font-weight:400;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{position:relative;display:inline}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;width:20px;left:0;opacity:0;position:absolute;top:0}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{content:"";position:absolute;top:-.1em;left:0;height:20px;width:20px;border:1px solid #bdbdbd}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{opacity:.4;cursor:not-allowed}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{content:"";border:3px solid #000;border-left:0;border-top:0;height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{padding:0 0 0 32px;margin:0;position:relative;cursor:pointer}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media (-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;width:100%;height:100%}*,:after,:before{box-sizing:inherit;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:g ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{display:flex;justify-content:space-between;align-items:center;min-height:48px;height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;justify-content:space-between;flex-direction:row}.active-filter-tags .flex-container .show-more-less{display:flex;justify-content:flex-start;align-content:flex-end;flex-direction:row;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{margin-top:5px;margin-left:5px;stroke:#b0c!important}.active-filter-tags .flex-container .show-more-less span{cursor:pointer;color:#b0c}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{cursor:pointer;color:#b0c}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{position:relative;height:520px;width:100%;margin-bottom:24px;box-shadow:inset 0 -1px 0 0 #e6e6e6;border:1px solid #e6e6e6}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;position:relative;width:100%;height:272px;overflow:hidden;flex-direction:column}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;justify-content:space-between;height:265px}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{position:absolute;z-index:1;top:32px;color:#fff;font-size:11px;font-style:italic;left:10px}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{position:absolute;top:10px;right:12px;height:55px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{position:relative;flex:0 0 45%;height:175px;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;position:inherit;padding-top:52px}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{position:absolute;max-width:80%;top:30%;left:11%;padding-top:0}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense .sds-text-field__icon_1{stroke:#532380}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{padding:8px;margin:16px 8px 16px 0;flex:1 1 50%;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{padding:8px;margin:16px 16px 16px 0;flex:1 1 50%;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4px}.bran ...
#
#           </style>
# <script defer="" src="/b6d68da27f43656bd907/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 5,
#         "trackInteractions": true
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta charset="utf-8" content="XBY2Wi8kQwg3BjsPDg4zHwgxPQk7LQ8h1EejZJppOStHcVvvrchkTDfF" csrf-param="_csrf_token" method-param="_method" name="csrf-token"/>
# </head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <button aria-controls="mobile-menu-section" aria-expanded="false" class="mobile-nav-menu-button" id="mobile-menu-button">
# <div class="mobile-nav-menu-open">
# <svg class="menu-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#menu"></use></svg>
# <span>Menu</span>
# </div>
# <div class="mobile-nav-menu-close hidden">
# <svg class="close-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# <span>Close</span>
# </div>
# </button>
# <div aria-labelledby="mobile-menu-button" class="global-header-menu-links" id="mobile-menu-section">
# <ul class="header-links-wrapper">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <div class="sign-in-up-out mobile">
# <a class="header-signin" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D20%26models%255B%255D%3D%26stock_type%3Dall%26zip%3D">Sign In</a>
# <span class="sign-in-out-divider">/</span>
# <a class="header-signup" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D20%26models%255B%255D%3D%26stock_type%3Dall%26zip%3D">Sign Up</a>
# </div>
# </div>
# </nav>
# </section>
# </header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <div data-phx-main="true" data-phx-session="SFMyNTY.....v7H0xdbO-DQaus16W5gGnENqmmsnwI9_QvsOIXbvtz4" data-phx-static="SFMyNTY.g2gDaAJhBHQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GcmY0NDRWb2xUUjlZbnhobgYASX3SJ30BYgABUYA.7djcp2tXcUtCexyuOrj-3TIlei1RNmblUT8JZDMnJiI" data-phx-view="Listing.SearchLive" id="phx-Frf444VolTR9Ynxh">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/vo2KpB8kxMZ9DObYJTUzahCOE1c.jpg" rel="preload"/>
# <section class="sds-page-section search-live" id="search-live-container">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [970, 250], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/mix.srp/top" data-appnexus-placement-id="17848514" data-hidden-on="" id="srp-top" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-srp-top" phx-update="ignore"></div>
# </div>
# </section>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="ModalBackdrop" phx-target="#srp-lead-form-modal">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# </div>
# </div>
# </div>
# <div phx-hook="LeadSubmissionTracker" phx_value_cid="srp-lead-form-modal"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div id="auth-completion-listener" phx-hook="AuthCompletionListener"></div>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one" data-activity-rule-type="custom" data-analytics-linkname="profiles-modal-close" data-component="profiles-modal" data-hook-callback="close_modal" id="auth-modal" phx-hook="ModalBackdrop" phx-target="#auth-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head">
# <div class="sds-icon--target btn-close" data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="profiles-modal-close" phx-click="close_modal" phx-target="#auth-modal" role="button">
# <span class="sds-icon">
# <svg height="24" width="24"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="sds-modal__content-body">
# <div class="sign-up">
# <h3 class="sds-heading--3 sds-heading--display sds-page-section__title">Create your account</h3>
# <div class="modal-body">
# <p class="sds-page-section__title--sub">
# Sign up access your saved searches anywhere, anytime, and from any device.
#     </p>
# <p class="sds-page-section__title--sub">
# Already have a profile? <a data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="modal-sign-in" href="#" phx-click="sign_in" phx-target="#auth-modal">Sign in</a>.
#     </p>
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D20%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dfacebook%26stock_type%3Dall%26zip%3D">
# <svg class="facebook-svg-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#facebook"></use></svg>Sign in with Facebook
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D20%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dgoogle%26stock_type%3Dall%26zip%3D">
# <svg fill="none" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M28.48 16.2955C28.48 15.3736 28.3973 14.4873 28.2436 13.6364H16V18.665H22.9964C22.695 20.29 21.7791 21.6668 20.4023 22.5886V25.8505H24.6036C27.0618 23.5873 28.48 20.2545 28.48 16.2955Z" fill="#4285F4" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 29C19.51 29 22.4527 27.8359 24.6036 25.8505L20.4023 22.5886C19.2382 23.3686 17.7491 23.8295 16 23.8295C12.6141 23.8295 9.74819 21.5427 8.72592 18.47H4.38274V21.8382C6.52183 26.0868 10.9182 29 16 29Z" fill="#34A853" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M8.72591 18.47C8.46591 17.69 8.31818 16.8568 8.31818 16C8.31818 15.1432 8.46591 14.31 8.72591 13.53V10.1618H4.38273C3.50227 11.9168 3 13.9023 3 16C3 18.0977 3.50227 20.0832 4.38273 21.8382L8.72591 18.47Z" fill="#FBBC05" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 8.17045C17.9086 8.17045 19.6223 8.82636 20.9696 10.1145L24.6982 6.38591C22.4468 4.28818 19.5041 3 16 3C10.9182 3 6.52183 5.91318 4.38274 10.1618L8.72592 13.53C9.74819 10.4573 12.6141 8.17045 16 8.17045Z" fill="#EA4335" fill-rule="evenodd"></path>
# </svg>
#   Sign in with Google
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-apple" href="/signin/apple_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3D20%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dapple%26stock_type%3Dall%26zip%3D">
# <svg height="44px" version="1.1" viewbox="0 -2 31 44" width="28px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Apple logo</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <path d="M15.7099491,14.8846154 C16.5675461,14.8846154 17.642562,14.3048315 18.28274,13.5317864 C18.8625238,12.8312142 19.2852829,11.852829 19.2852829,10.8744437 C19.2852829,10.7415766 19.2732041,10.6087095 19.2490464,10.5 C18.2948188,10.5362365 17.1473299,11.140178 16.4588366,11.9494596 C15.9152893,12.56548 15.4200572,13.5317864 15.4200572,14.5222505 C15.4200572,14.6671964 15.4442149,14.8121424 15.4562937,14.8604577 C15.5166879,14.8725366 15.6133185,14.8846154 15.7099491,14.8846154 Z M12.6902416,29.5 C13.8618881,29.5 14.3812778,28.714876 15.8428163,28.714876 C17.3285124,28.714876 17.6546408,29.4758423 18.9591545,29.4758423 C20.2395105,29.4758423 21.0971074,28.292117 21.9063891,27.1325493 C22.8123013,25.8038779 23.1867451,24.4993643 23.2109027,24.4389701 C23.1263509,24.4148125 20.6743484,23.4122695 20.6743484,20.5979021 C20.6743484,18.1579784 22.6069612,17.0588048 22.7156707,16.974253 C21.4353147,15.1382708 19.490623,15.0899555 18.9591545,15.0899555 C17.5217737,15.0899555 16.3501271,15.9596313 15.6133185,15.9596313 C14.8161157,15.9596313 13.7652575,15.1382708 12.521138,15.1382708 C10.1536872,15.1382708 7.75,17.0950413 7.75,20.7911634 C7.75,23.0861411 8.64383344,25.513986 9.74300699,27.0842339 C10.6851558,28.4129053 11.5065162,29.5 12.6902416,29.5 Z" fill="#FFFFFF" fill-rule="nonzero" id=""></path>
# </g>
# </svg>
#   Sign in with Apple
# </a>
# </li>
# </ul>
# <div class="separator-wrapper">
# <div class="sds-separator"></div>
# <div class="separator-text">Or</div>
# <div class="sds-separator"></div>
# </div>
# <form action="#" method="post" phx-submit="sign_up_continue" phx-target="#auth-modal"><input name="_csrf_token" type="hidden" value="XBY2Wi8kQwg3BjsPDg4zHwgxPQk7LQ8h1EejZJppOStHcVvvrchkTDfF"/>
# <div class="sds-field-group">
# <div class="sds-field email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="account" id="user_email" maxlength="255" name="user[email]" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# </div>
# <div class="actions">
# <div class="sds-field">
# <button class="sds-button" type="submit">Continue</button>
# </div>
# </div>
# </form>
# <div class="disclaimer">
# <div class="sds-disclaimer">
# By signing up, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
#    and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-premier-dealer-search="no_premier_dealer_found" data-props='{"selected_refinement":null}' data-search-instance-id="3d204977-0cfc-4f31-a7d9-9fd38f97fcaf" data-search-type="general-inventory-search" data-site-activity='{"listing_ids":["62c8f7af-da19-48be-b13c-2e7f5e8ef29a","4a3bd27c-20ba-4435-83e6-d84f166228c0","81ef1baa-10b4-418c-8a70-fbf5441b2983","cd5e8408-017e-467c-bbdc-e1803244d4c9","ef9d3b56-5e44-4c1b-a8a0-2b0d1bf31e02","2bb316c9-e38f-4066-84eb-8280af4c2f30","430dad9d-6978-4c87-a4ba-e59416df0ac6","1cc939e7-7c2e-49bf-9403-a63f08bfbfa7","60f48245-2ab2-4af9-bb78-d20a55a231b5","dbf37ffe-b250-494c-b95c-d208938074be","b4bc2be1-eace-4da3-bb27-14051cf5f354","fb6fe8e9-f8f9-467d-ad98-79a73cba401b","93c3f1d6-9027-4e01-b90a-add8c1e0911e","77ce6fca-464f-4079-8d8c-e0c45eaf34d4","f5efd3f8-7d63-44cf-9ac2-30e1b4eb7d7a","cb7a0631-c424-4a24-9177-5489c074839d","a05f7bfa-dec6-46b9-82f6-a879f3c9fef4","46618297-9c0f-4760-90c5-e8faf6f337a2","9498d528-20eb-41e1-be64-1c962c4e330a","ea47a937-90be-4d2a-a4fc-cd98f9aede22"],"search_results_on_page":20,"stock_sub":"","web_page_type_from":"","cpo_indicator":true,"model_group":"mercedes_benz-c_all","exterior_color":"","filter_category_value":"","search_min_year":"","multipleVehicles":true,"search_makes":"mercedes_benz","stock_type":"","features":"","sort_order":"desc","search_make_models":"","result_per_page":20,"sort_field":"searchRank1","result_page_count":500,"price":"","interiorColor":"","search_bodystyles":"","fuel_type":"","search_make_model_trims":[{"make":"mercedes_benz"}],"search_make_model_groups":"","seller_type":"","search_max_year":"","model":"","search_trims":"","total_results":10000,"search_models":"","search_stock_type_standard":"all","result_page_number":1,"search_stock_sub":"","vehicleArray":[{"badges":["good_deal","price_drop_in_cents"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:S-Class:S 550","cat":"luxurypassenger_plus","certified_preowned":false,"cpo_indicator":false,"customer_id":"2232","exterior_color":"Black","fuel_type":"Gasoline","listing_id":"62c8f7af-da19-48be-b13c-2e7f5e8ef29a","make":"Mercedes-Benz","mileage":"32923","model":"S-Class","msrp":null,"price":"41444","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":"S 550","vin":"WDDUG8CB1GA274813","year":"2016"},{"badges":["good_deal","virtual_appt","price_drop_in_cents","home_delivery"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:CLA 250:Base 4MATIC","cat":"luxurypassenger_standard","certified_preowned":false,"cpo_indicator":false,"customer_id":"5394772","exterior_color":"Polar Silver Metallic","fuel_type":"E85 Flex Fuel","listing_id":"4a3bd27c-20ba-4435-83e6-d84f166228c0","make":"Mercedes-Benz","mileage":"16532","model":"CLA 250","msrp":null,"price":"32937","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":"Base 4MATIC","vin":"WDDSJ4GB0KN701802","year":"2019"},{"badges":["great_deal","virtual_appt","home_delivery"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:C-Class:C 300 4MATIC","cat":"luxurypassenger_standard","certified_preowned":false,"cpo_indicator":false,"customer_id":"5395461","exterior_color":"Gray","fuel_type":"Gasoline","listing_id":"81ef1baa-10b4-418c-8a70-fbf5441b2983","make":"Mercedes-Benz","mileage":"42591","model":"C-Class","msrp":null,"price":"23950","seller_type":"dealership","sponsored":false,"stock_sub":"","stock_type":"Used","trim":"C 300 4MATIC","vin":"55SWF4KB2JU247679","year":"2018"},{"badges":["good_deal"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:C-Class:C 300","cat":"luxurypassenger_standard","certified_preowned":false,"cpo_indicator":false,"customer_id":"104579","exterior_color":"Blue","fuel_type":"Gasoline","listing_id":"cd5e8408-017e-467c-bbdc-e1803244d4c9","make":"Mercedes-Benz","mileage":"35878","model":"C-Class","msrp":"40400","price":"25990","seller_type":"dealership","sponsored":f ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2016 Mercedes-Benz S-Class S 550","position":1,"url":"https://www.cars.com/vehicledetail/62c8f7af-da19-48be-b13c-2e7f5e8ef29a/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=0/"},{"@type":"ListItem","name":"2019 Mercedes-Benz CLA 250 Base 4MATIC","position":2,"url":"https://www.cars.com/vehicledetail/4a3bd27c-20ba-4435-83e6-d84f166228c0/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=1/"},{"@type":"ListItem","name":"2018 Mercedes-Benz C-Class C 300 4MATIC","position":3,"url":"https://www.cars.com/vehicledetail/81ef1baa-10b4-418c-8a70-fbf5441b2983/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=2/"},{"@type":"ListItem","name":"2015 Mercedes-Benz C-Class C 300","position":4,"url":"https://www.cars.com/vehicledetail/cd5e8408-017e-467c-bbdc-e1803244d4c9/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=3/"},{"@type":"ListItem","name":"2015 Mercedes-Benz M-Class ML 350 4MATIC","position":5,"url":"https://www.cars.com/vehicledetail/ef9d3b56-5e44-4c1b-a8a0-2b0d1bf31e02/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=4/"},{"@type":"ListItem","name":"2016 Mercedes-Benz GL-Class GL 450 4MATIC","position":6,"url":"https://www.cars.com/vehicledetail/2bb316c9-e38f-4066-84eb-8280af4c2f30/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=5/"},{"@type":"ListItem","name":"2018 Mercedes-Benz C-Class C 300","position":7,"url":"https://www.cars.com/vehicledetail/430dad9d-6978-4c87-a4ba-e59416df0ac6/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=6/"},{"@type":"ListItem","name":"2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe","position":8,"url":"https://www.cars.com/vehicledetail/1cc939e7-7c2e-49bf-9403-a63f08bfbfa7/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=7/"},{"@type":"ListItem","name":"2009 Mercedes-Benz M-Class 3.5L","position":9,"url":"https://www.cars.com/vehicledetail/60f48245-2ab2-4af9-bb78-d20a55a231b5/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=8/"},{"@type":"ListItem","name":"2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe","position":10,"url":"https://www.cars.com/vehicledetail/dbf37ffe-b250-494c-b95c-d208938074be/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=9/"},{"@type":"ListItem","name":"2017 Mercedes-Benz SL 450 Base","position":11,"url":"https://www.cars.com/vehicledetail/b4bc2be1-eace-4da3-bb27-14051cf5f354/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=10/"},{"@type":"ListItem","name":"2012 Mercedes-Benz GLK-Class GLK 350","position":12,"url":"https://www.cars.com/vehicledetail/fb6fe8e9-f8f9-467d-ad98-79a73cba401b/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=11/"},{"@type":"ListItem","name":"2012 Mercedes-Benz GLK-Class GLK 350","position":13,"url":"https://www.cars.com/vehicledetail/93c3f1d6-9027-4e01-b90a-add8c1e0911e/?results_page_number=1&search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&search_zipcode=&sponsored%3F=false&vertical_position=12/"},{"@type":"ListItem","name":"2016 Mercedes-Benz S-C ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Black","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/vo2KpB8kxMZ9DObYJTUzahCOE1c.jpg"},"name":"2016 Mercedes-Benz S-Class","vehicleIdentificationNumber":"WDDUG8CB1GA274813"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Polar Silver Metallic","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/dfcccf28-02bc-5ff5-a2b5-c78036267c06/2d0e380d-1505-4063-af0e-1a0332296c87/dW5ljaUML5poxPaRH6iS9KDFAm4.jpg"},"name":"2019 Mercedes-Benz CLA 250","vehicleIdentificationNumber":"WDDSJ4GB0KN701802"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Gray","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/0b32085c-e982-5bac-863c-b1da1d61bb63/b62627ef-516b-452e-98e2-4ab19097205d/Jm-Rq5eL92Kswb7iK6w1dwsTENc.jpg"},"name":"2018 Mercedes-Benz C-Class","vehicleIdentificationNumber":"55SWF4KB2JU247679"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Blue","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/5ed2052f-6d94-56a1-ae79-2c8c9b93384e/75445023-e16b-40cc-827d-470948d3eb86/qCU_nF5L8xkjtr54e8Sbpb5y3A4.jpg"},"name":"2015 Mercedes-Benz C-Class","vehicleIdentificationNumber":"55SWF4KB2FU058182"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Black","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/4cc2c83b-0c24-5b77-a836-835f66f64a44/66d3c029-6621-4c2f-8e6b-87fdb6ccda48/QCbCcapMHAwYR2XVhFLJqtyBHy4.jpg"},"name":"2015 Mercedes-Benz M-Class","vehicleIdentificationNumber":"4JGDA5HBXFA460346"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"White","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/c4cc292f-843a-53da-96d7-99e424d8c7a5/90062854-a7c9-4499-a537-fd81c575d7f7/18cwjjPNmPKpIDYZSHAEPqcdO9Q.jpg"},"name":"2016 Mercedes-Benz GL-Class","vehicleIdentificationNumber":"4JGDF6EE2GA655056"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Black","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/ce908d08-ec30-5154-ac63-05e59a9b5fc7/42c9e82a-6e00-4e10-a379-6b95e65dee76/UEslloFe93v5LLHKQYrP3kcEgR8.jpg"},"name":"2018 Mercedes-Benz C-Class","vehicleIdentificationNumber":"WDDWJ4JB3JF661735"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Polar White","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/88d87da8-50d5-5a96-b81d-174d1b3024c7/40590f8d-7fb1-4644-8b30-35a98506bf93/SZmEZWolE9fbhRJvcXzYExSJ1z4.jpg"},"name":"2019 Mercedes-Benz AMG GLE 43","vehicleIdentificationNumber":"4JGED6EBXKA154389"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Black","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/8137165e-fbe5-5af4-9ba2-669363e8e176/a41b66e5-5a97-480f-8207-6af541c9c0ea/LnNLZsmARfm2IGgYONdrJBZRYLU.jpg"},"name":"2009 Mercedes-Benz M-Class","vehicleIdentificationNumber":"4JGBB86E89A473605 ...
# <nav class="search-filter-bar">
# <button class="" data-activity-rule-type="custom" data-component="save-search-add" data-linkname="save-search-sign-up" id="search_filter_bar_save_search_button" phx-click="save_search" phx-target="#saved_search">
#   Save search
# </button>
# <button phx-click="show_sort_overlay">
# Sort
#     </button>
# <button id="show-search-form-overlay" phx-click="show_search_form_overlay" phx-hook="ShowSearchFormOverlay">
# Filter
#     </button>
# </nav>
# <header class="sds-page-section__header">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="Home" href="/">Home</a></span>
# </li>
# <li aria-current="page">Cars for Sale</li>
# </ul>
# </nav>
# <script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://www.cars.com/","name":"Home"},"position":1},{"@type":"ListItem","item":{"@id":"https://www.cars.com/shopping/","name":"Cars for Sale"},"position":2}]}
# </script>
# <div class="heading-container">
# <h1 class="sds-heading--1 sds-page-section__title">New and used Mercedes-Benz for sale</h1>
# <form action="#" class="sort-form" id="desktop_sort" method="post" phx-change="sort_form_change"><input name="_csrf_token" type="hidden" value="XBY2Wi8kQwg3BjsPDg4zHwgxPQk7LQ8h1EejZJppOStHcVvvrchkTDfF"/>
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" data-activitykey="sort-dropdown" data-component="sort-apply" id="sort-dropdown" name="sort" phx-page-loading=""><option selected="" value="best_match_desc">Best match</option><option value="list_price">Lowest price</option><option value="list_price_desc">Highest price</option><option value="mileage">Lowest mileage</option><option value="mileage_desc">Highest mileage</option><option value="distance">Nearest location</option><option value="best_deal">Best deal</option><option value="year_desc">Newest year</option><option value="year">Oldest year</option><option value="listed_at_desc">Newest listed</option><option value="listed_at">Oldest listed</option></select>
# <label class="sds-label" for="sort-dropdown">Sort by</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </form>
# </div>
# <span class="total-entries">
# 10,000+ matches
#       </span>
# </header>
# <div class="sds-page-section__content">
# <div class="vehicle-cards" data-tracking-orientation="vertical" id="vehicle-cards-container" phx-update="replace">
# <div class="save-search-banner">
# <div class="header">
# <svg aria-describedby="duotone-search_description" aria-labelledby="duotone-search_title" class="duotone search" role="img" viewbox="0 0 31 41" xmlns="http://www.w3.org/2000/svg">
# <title id="duotone-search_title">duotone-search</title>
# <desc id="duotone-search_description">A stylized magnifying glass.</desc>
# <polygon class="cls-1" fill="#250858" id="Rectangle" points="16.79 24.15 19.68 22.91 25.54 30.42 22.64 31.66 16.79 24.15"></polygon>
# <path class="cls-2" d="M24.39,27.5l6.15,10.33h0l-4.61,2.58L19.81,30.12a1,1,0,0,1,.35-1.37h0L23,27.14A1,1,0,0,1,24.39,27.5Z" fill="#00bfde" id="path-1"></path>
# <path class="cls-3" d="M6.87,1.84a13.75,13.75,0,1,1-5,18.79A13.76,13.76,0,0,1,6.87,1.84ZM8.75,5.09A10,10,0,1,0,22.41,8.75,10,10,0,0,0,8.75,5.09Z" fill="#532380" id="Combined-Shape"></path>
# </svg>
# <div class="message">
# <strong>Save your search</strong>
#  to easily start where you left off, get updates on new inventory &amp; price drops.
#             </div>
# </div>
# <button class="sds-button--secondary sds-button--dense" data-activity-rule-type="custom" data-component="save-search-add" data-linkname="save-search-sign-up" id="banner_save_search_button" phx-click="save_search" phx-target="#saved_search">
#   Sign up
# </button>
# </div>
# <div class="vehicle-card" data-listing-id="62c8f7af-da19-48be-b13c-2e7f5e8ef29a" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="62c8f7af-da19-48be-b13c-2e7f5e8ef29a" phx-hook="VehicleCard" phx-target="5">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/62c8f7af-da19-48be-b13c-2e7f5e8ef29a/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 32 of 2016 Mercedes-Benz S-Class S 550" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 32 of 2016 Mercedes-Benz S-Class S 550" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/vo2KpB8kxMZ9DObYJTUzahCOE1c.jpg"/>
# </div>
# <div aria-label="Photo 2 of 32 of 2016 Mercedes-Benz S-Class S 550" class="image-wrap" data-index="1">
# <img alt="Photo 2 of 32 of 2016 Mercedes-Benz S-Class S 550" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/nt1KNiAWGBkioIuXuOAD15RKKZY.jpg"/>
# </div>
# <div aria-label="Photo 3 of 32 of 2016 Mercedes-Benz S-Class S 550" class="image-wrap" data-index="2">
# <img alt="Photo 3 of 32 of 2016 Mercedes-Benz S-Class S 550" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/iDtPG8pBEthlDGg-r_T_XwxvYnA.jpg"/>
# </div>
# <div aria-label="Photo 4 of 32 of 2016 Mercedes-Benz S-Class S 550" class="image-wrap" data-index="3">
# <img alt="Photo 4 of 32 of 2016 Mercedes-Benz S-Class S 550" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/s-6zl3ykucc8RueuY7AAitmGqIg.jpg"/>
# </div>
# <div aria-label="Photo 5 of 32 of 2016 Mercedes-Benz S-Class S 550" class="image-wrap" data-index="4">
# <img alt="Photo 5 of 32 of 2016 Mercedes-Benz S-Class S 550" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/2-i8akNc-Ah-ss7vfsml0ZnaZwM.jpg"/>
# </div>
# <div aria-label="Photo 6 of 32 of 2016 Mercedes-Benz S-Class S 550" class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/e650193a-8da2-5a4f-b1f2-86e5079b1200/39123cc1-bf51-4436-b238-04c13faf97f4/vuu83vO2oYfLjAwXV95qU1ZR9-Q.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">View all 32 photos</div>
# </div>
# </div>
# </div>
# <button class="image-control-left">
# <div class="rectangle rectangle-left">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <button class="image-control-right">
# <div class="rectangle rectangle-right">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/32</div>
# <div class="gallery-nav">
# <div class="image-indicator selected"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# </div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="62c8f7af-da19-48be-b13c-2e7f5e8ef29a" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="83" phx-value-is_vdp="false" phx-value-listing_id="62c8f7af-da19-48be-b13c-2e7f5e8ef29a">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">Used</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/62c8f7af-da19-48be-b13c-2e7f5e8ef29a/?results_page_number=1&amp;search_instance_id=3d204977-0cfc-4f31-a7d9-9fd38f97fcaf&amp;search_zipcode=&amp;sponsored%3F=false&amp;vertical_position=1" rel="nofollow">
# <h2 class="title">2016 Mercedes-Benz S-Class S 550</h2>
# </a>
# <div class="mileage">32,923 mi.</div>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$41,444</span>
# <span class="secondary-price price-drop">$1,000 price drop</span>
# </div>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents="{&quot;price_badge&quot;:{&quot;price_badge&quot;:&quot;competitively&quot;,&quot;price_badge_description&quot;:&quot;This car presents a good buying opportunity. Our analysis compares this car's price, features, and condition with similar 2016 S-Class.&quot;,&quot;price_badge_savings_icon_text&quot;:&quot;&quot;,&quot;price_badge_text&quot;:&quot;Good&quot;,&quot;price_badge_text_lowercase&quot;:&quot;good&quot;,&quot;price_savings_text&quot;:&quot;&quot;,&quot;svg_tag&quot;:&quot;&lt;svg class=\&quot;sds-text-field__icon\&quot; height=\&quot;16\&quot; width=\&quot;16\&quot;&gt;&lt;use xlink:href=\&quot;/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right-thick\&quot;&gt;&lt;/use&gt;&lt;/svg&gt;&quot;},&quot;href_to_vdp&quot;:{&quot;href_to_vdp&quot;:&quot;/vehicledetail/62c8f7af-da19-48be-b13c-2e7f5e8ef29a/?bodystyle=sedan&amp;cpo_indicator=false&amp;customer_id=2232&amp;intent_id=badges-explainer&amp;listing_id=62c8f7af-da19-48be-b13c-2e7f5e8ef29a&amp;make=mercedes_benz&amp;model=s_class&amp;model_year=2016&amp;msrp=&amp;price=41444&amp;sponsored%3F=false&amp;stock_type=used&amp;trim=s+550&quot;}}" data-override-payload='{"bodystyle":"sedan","cpo_indicator":false,"customer_id":"2232","horizontal_position":null,"listing_id":"62c8f7af-da19-48be-b13c-2e7f5e8ef29a","make":"mercedes_benz","model":"s_class","model_year":"2016","msrp":null,"price":"41444","results_page_number":1,"sponsored?":false,"stock_type":"used","trim":"s 550","vertical_position":1,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div aria-label="price_badge" class="sds-badge sds-badge--icon sds-badge--good js-price-badging" data-linkname="price-badge-good">
# <div class="sds-badge__icon">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right-thick"></use></svg>
# </div>
# <span class="sds-badge__label">Good Deal<span class="sds-badge--price-savings"></span></span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# <div class="vehicle-deeplink">
# <a aria-describedby="new-tab-link" aria-label="Free CARFAX Report, External link" class="sds-link--ext" data-intent-id="srp-vehicle-history-report" data-linkname="vehicle-history" data-override-payload='{"page_url":"https://www.carfax.com/VehicleHistory/ar20/xqc8EhVlokI2MVqBHDTxC9ybSc_bl_EOXE7ETm8CndBXNSzkKHTNkR1QFb1kxF7079g6rEqg9cQ1WUuB6qWEX8X15BRqmwZM3Gk"}' href="/external/carfax/?redirect=https%3A%2F%2Fwww.carfax.com%2FVehicleHistory%2Far20%2Fxqc8EhVlokI2MVqBHDTxC9ybSc_bl_EOXE7ETm8CndBXNSzkKHTNkR1QFb1kxF7079g6rEqg9cQ1WUuB6qWEX8X15BRqmwZM3Gk" rel="noopener nofollow" target="_blank">Free CARFAX Report<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a>
# </div>
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Auto Buying Service</strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">4.8</span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# ...
# </div>
# <div aria-labelledby="footer-header-2" class="accordion-panel" hidden="" id="footer-section-2" role="region">
# <ul class="global-footer-list sds-list">
# <li><a aria-describedby="new-tab-link" aria-label="Grow with CARS, External link" class="sds-link--ext" data-activity-rule-type="custom" data-linkname="footer-grow-with-cars" href="https://www.growwithcars.com" rel="noopener" target="_blank">Grow with CARS<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Login, External link" class="sds-link--ext" data-activity-rule-type="custom" data-linkname="footer-dealer-login" href="https://dealerdash.cars.com/" rel="noopener" target="_blank">Dealer Login<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# <div class="accordion-group">
# <div aria-controls="footer-section-3" aria-expanded="false" class="accordion-header" id="footer-header-3" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Explore Our Brand</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-3" class="accordion-panel" hidden="" id="footer-section-3" role="region">
# <ul class="global-footer-list sds-list">
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Inspire, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="1" data-linkname="footer-dealer-inspire" href="https://www.dealerinspire.com/" rel="noopener" target="_blank">Dealer Inspire<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="DealerRater, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="2" data-linkname="footer-dealerrater" href="https://www.dealerrater.com/" rel="noopener" target="_blank">DealerRater<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="FUEL, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">FUEL<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Auto.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">Auto.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="NewCars.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">NewCars.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Pickuptrucks.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">Pickuptrucks.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Our Company</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">About Cars.com</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">Contact Cars.com</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Investor Relations, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">Investor Relations<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2021 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_afw2Gp67tcpDXi5" height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src=""></script>
# <link data-href="/b6d68da27f43656bd907/css/common.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="/b6d68da27f43656bd907/css/srp.css?vsn=d" media="print" rel="stylesheet"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"aff_code":"national","cat":null,"customer_id":"","designated_market_area_key":null,"lat_long":"/","local_zone":null,"loginStatus":false,"make":"","market_name":null,"marketing_click_data":null,"marketing_click_id":"","marketing_referral_source":"","model":"","page_channel":"shopping","page_detail":null,"page_key":"search-results","page_name":"shopping/search-results","page_type":"shopping/search-results","platform_id":"cars_responsive","profileAccountType":null,"trip_id":"","url_base":"","url_referer":"","useragent":"","utm_campaign":null,"utm_content":null,"utm_medium":null,"utm_source":null,"utm_term":null,"year":"","zip_ip2geo":null}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"results_page_count":500,"utm_medium":null,"als_private_data":"QTEyOEdDTQ.p3YvUhe4LYyj1plC9yRMi2N-lyWLI7sqFcmMS4WHN1_SeM_aihyS1d3svuM.yg2pVCuzY2xnseSp.WHNhuRNd0TwRh811jIpBiYllM8657XVLMoIM8-6zrJqwlgumjEBYqWCXfi5jm5iKdQwhsA.5FmuoV3OmDrjRg3ZuEQ2hg","latitude":null,"web_page_type_from":"","roxanne_visitor_id":"","cpo_indicator":true,"app_version":null,"experiment_ids":"null","trip_id":"","customer_id":"","results_per_page":20,"web_page_type_to":"shopping/search-results","results_page_number":1,"model_year":"","stock_type":"","device_id":null,"aff_code":"national","longitude":null,"profile_user_id":null,"horizontal_position":"","utm_source":null,"utm_content":null,"incentive_ids":"","price":null,"listing_id":"","pdid":null,"device_model":null,"timestamp_utc":1637050645900,"is_bot":true,"device_os":null,"roxanne_visit_id":"","adobe_id":null,"model":"","page_instance_id":"Frf444UPvQejfWICpHxB","total_results":10000,"bot_type":"Unknown Bot (python-reque_B8E4201CA3B8EDF5DEAEE8E277BFB3CD):monitor:Behavior Anomaly;HTTP Libraries:100:aggressive","msrp":"","marketing_click_id":"","utm_campaign":null,"page_url":"https://www.cars.com/shopping/results/?stock_type=all&amp;makes[]=mercedes_benz&amp;models[]=&amp;list_price_max=&amp;maximum_distance=20&amp;zip=","useragent":"python-requests/2.24.0","x_forwarded_for":null,"device_type":"desktop","carrier":null,"vertical_position":"","upsells":[],"search_zipcode":"","referer_url":"","ga_client_id":null,"search_instance_id":null,"internet_connection":null,"make":"","bodystyle":"","trim":"","platform_id":"cars_responsive","marketing_click_source":"","utm_term":null}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#
# </script>
# <script src="/GxlM9QiR/v-BjI2w/JTv9e5R/sA/3rpiVfQ2/DUgiAQ/WjgyGzQ/0J30B" type="text/javascript"></script></link></body>
# </html>

# %%
results = soup.find_all('div',{'class':'vehicle-card'})

# %%
len(results)
# Out:
# 20

# %% [markdown]
# # Name of car

# %%
results[0].find('h2')
# Out:
# <h2 class="title">2016 Mercedes-Benz S-Class S 550</h2>

# %%
results[0].find('h2').get_text() #Just to get only the text
# Out:
# '2016 Mercedes-Benz S-Class S 550'

# %% [markdown]
# # KM it has run

# %%
results[0].find('div',{'class':'mileage'})
# Out:
# <div class="mileage">32,923 mi.</div>

# %%
results[0].find('div',{'class':'mileage'}).get_text()
# Out:
# '32,923 mi.'

# %% [markdown]
# # Rating

# %%
results[0].find('span',{'class':'sds-rating__count'})
# Out:
# <span class="sds-rating__count">4.8</span>

# %%
results[0].find('span',{'class':'sds-rating__count'}).get_text()
# Out:
# '4.8'

# %% [markdown]
# # Number of rating

# %%
results[0].find('span',{'class':'sds-rating__link sds-button-link'})
# Out:
# <span class="sds-rating__link sds-button-link">(135 reviews)</span>

# %%
results[0].find('span',{'class':'sds-rating__link sds-button-link'}).get_text()
# Out:
# '(135 reviews)'

# %% [markdown]
# # Price

# %%
results[0].find('span',{'class':'primary-price'})
# Out:
# <span class="primary-price">$41,444</span>

# %%
results[0].find('span',{'class':'primary-price'}).get_text()
# Out:
# '$41,444'

# %% [markdown]
# # Dealer

# %%
results[0].find('div',{'class':'dealer-name'})
# Out:
# <div class="dealer-name">
# <strong>Auto Buying Service</strong>
# </div>

# %%
results[0].find('div',{'class':'dealer-name'}).get_text()
# Out:
# '\nAuto Buying Service\n'

# %%
# Combining all together

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('NA')
        
     #mileage
    try:
        mileage.append(result.find('div',{'class':'mileage'}).get_text())
    except:
        mileage.append('NA')   
        
     #dealer_name
    try:
        dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
    except:
        dealer_name.append('NA')  
        
     #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('NA')  
        
    #review Count
    try:
        review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
    except:
        review_count.append('NA') 
        
    #Price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

# %%
car_dealer
# Out:
#                                           Name      mileage  \
# 0             2016 Mercedes-Benz S-Class S 550   32,923 mi.
# 1       2019 Mercedes-Benz CLA 250 Base 4MATIC   16,532 mi.
# 2      2018 Mercedes-Benz C-Class C 300 4MATIC   42,591 mi.
# 3             2015 Mercedes-Benz C-Class C 300   35,878 mi.
# 4     2015 Mercedes-Benz M-Class ML 350 4MATIC   60,013 mi.
# 5    2016 Mercedes-Benz GL-Class GL 450 4MATIC   65,233 mi.
# 6             2018 Mercedes-Benz C-Class C 300   46,558 mi.
# 7   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe   19,761 mi.
# 8              2009 Mercedes-Benz M-Class 3.5L  135,426 mi.
# 9   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe   37,786 mi.
# 10              2017 Mercedes-Benz SL 450 Base   46,081 mi.
# 11        2012 Mercedes-Benz GLK-Class GLK 350   64,083 mi.
# 12        2012 Mercedes-Benz GLK-Class GLK 350   72,507 mi.
# 13     2016 Mercedes-Benz S-Class S 550 4MATIC   62,492 mi.
# 14      2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 15     2015 Mercedes-Benz S-Class S 550 4MATIC   57,227 mi.
# 16            2016 Mercedes-Benz E-Class E 350   48,979 mi.
# 17      2017 Mercedes-Benz GLE 350 Base 4MATIC   64,804 mi.
# 18            2018 Mercedes-Benz E-Class E 300   48,749 mi.
# 19   2014 Mercedes-Benz GL-Class GL 450 4MATIC   74,000 mi.
#
#                            Dealer_name Rating     Review_count    Price
# 0              \nAuto Buying Service\n    4.8    (135 reviews)  $41,444
# 1       \nDARCARS Lexus of Greenwich\n    4.6     (39 reviews)  $32,937
# 2                \nJamaica 26 Motors\n    3.3     (28 reviews)  $23,950
# 3             \nBourne's Auto Center\n    4.9  (4,180 reviews)  $25,990
# 4      \nMercedes-Benz of Naperville\n    4.6    (491 reviews)  $29,000
# 5                \nMerlex Auto Group\n    3.8    (533 reviews)  $33,499
# 6             \nGo Luxury Auto Group\n    5.0      (2 reviews)  $38,995
# 7         \nMercedes-Benz of Ontario\n    4.9  (1,861 reviews)  $80,388
# 8                    \nEmpire Motors\n    4.3     (60 reviews)   $9,499
# 9                    \nWalter's Audi\n    4.9  (3,122 reviews)  $69,911
# 10      \nMercedes-Benz of Asheville\n    4.1     (72 reviews)  $62,997
# 11  \nHolman Honda of Ft. Lauderdale\n    4.7  (2,086 reviews)  $16,550
# 12                     \nAE of Miami\n    2.7     (31 reviews)   $7,450
# 13          \nGravity Autos Marietta\n    4.0    (130 reviews)  $49,799
# 14         \nKoons Ford of Baltimore\n    4.8  (1,549 reviews)  $33,500
# 15             \nAuto Buying Service\n    4.8    (135 reviews)  $34,444
# 16       \nAutolenders Lawrenceville\n    4.9    (478 reviews)  $26,495
# 17      \nJaguar Land Rover Buckhead\n    4.6    (170 reviews)  $34,900
# 18                \nMazzei Chevrolet\n    2.6      (8 reviews)  $34,853
# 19           \nFred's Executive Auto\n    4.6    (384 reviews)  $29,750

# %%
car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                           Name      mileage  \
# 0             2016 Mercedes-Benz S-Class S 550   32,923 mi.
# 1       2019 Mercedes-Benz CLA 250 Base 4MATIC   16,532 mi.
# 2      2018 Mercedes-Benz C-Class C 300 4MATIC   42,591 mi.
# 3             2015 Mercedes-Benz C-Class C 300   35,878 mi.
# 4     2015 Mercedes-Benz M-Class ML 350 4MATIC   60,013 mi.
# 5    2016 Mercedes-Benz GL-Class GL 450 4MATIC   65,233 mi.
# 6             2018 Mercedes-Benz C-Class C 300   46,558 mi.
# 7   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe   19,761 mi.
# 8              2009 Mercedes-Benz M-Class 3.5L  135,426 mi.
# 9   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe   37,786 mi.
# 10              2017 Mercedes-Benz SL 450 Base   46,081 mi.
# 11        2012 Mercedes-Benz GLK-Class GLK 350   64,083 mi.
# 12        2012 Mercedes-Benz GLK-Class GLK 350   72,507 mi.
# 13     2016 Mercedes-Benz S-Class S 550 4MATIC   62,492 mi.
# 14      2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 15     2015 Mercedes-Benz S-Class S 550 4MATIC   57,227 mi.
# 16            2016 Mercedes-Benz E-Class E 350   48,979 mi.
# 17      2017 Mercedes-Benz GLE 350 Base 4MATIC   64,804 mi.
# 18            2018 Mercedes-Benz E-Class E 300   48,749 mi.
# 19   2014 Mercedes-Benz GL-Class GL 450 4MATIC   74,000 mi.
#
#                            Dealer_name Rating Review_count    Price
# 0              \nAuto Buying Service\n    4.8         135   $41,444
# 1       \nDARCARS Lexus of Greenwich\n    4.6          39   $32,937
# 2                \nJamaica 26 Motors\n    3.3          28   $23,950
# 3             \nBourne's Auto Center\n    4.9       4,180   $25,990
# 4      \nMercedes-Benz of Naperville\n    4.6         491   $29,000
# 5                \nMerlex Auto Group\n    3.8         533   $33,499
# 6             \nGo Luxury Auto Group\n    5.0           2   $38,995
# 7         \nMercedes-Benz of Ontario\n    4.9       1,861   $80,388
# 8                    \nEmpire Motors\n    4.3          60    $9,499
# 9                    \nWalter's Audi\n    4.9       3,122   $69,911
# 10      \nMercedes-Benz of Asheville\n    4.1          72   $62,997
# 11  \nHolman Honda of Ft. Lauderdale\n    4.7       2,086   $16,550
# 12                     \nAE of Miami\n    2.7          31    $7,450
# 13          \nGravity Autos Marietta\n    4.0         130   $49,799
# 14         \nKoons Ford of Baltimore\n    4.8       1,549   $33,500
# 15             \nAuto Buying Service\n    4.8         135   $34,444
# 16       \nAutolenders Lawrenceville\n    4.9         478   $26,495
# 17      \nJaguar Land Rover Buckhead\n    4.6         170   $34,900
# 18                \nMazzei Chevrolet\n    2.6           8   $34,853
# 19           \nFred's Executive Auto\n    4.6         384   $29,750

# %%
car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

# %%
car_dealer
# Out:
#                                           Name      mileage  \
# 0             2016 Mercedes-Benz S-Class S 550   32,923 mi.
# 1       2019 Mercedes-Benz CLA 250 Base 4MATIC   16,532 mi.
# 2      2018 Mercedes-Benz C-Class C 300 4MATIC   42,591 mi.
# 3             2015 Mercedes-Benz C-Class C 300   35,878 mi.
# 4     2015 Mercedes-Benz M-Class ML 350 4MATIC   60,013 mi.
# 5    2016 Mercedes-Benz GL-Class GL 450 4MATIC   65,233 mi.
# 6             2018 Mercedes-Benz C-Class C 300   46,558 mi.
# 7   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe   19,761 mi.
# 8              2009 Mercedes-Benz M-Class 3.5L  135,426 mi.
# 9   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe   37,786 mi.
# 10              2017 Mercedes-Benz SL 450 Base   46,081 mi.
# 11        2012 Mercedes-Benz GLK-Class GLK 350   64,083 mi.
# 12        2012 Mercedes-Benz GLK-Class GLK 350   72,507 mi.
# 13     2016 Mercedes-Benz S-Class S 550 4MATIC   62,492 mi.
# 14      2017 Mercedes-Benz GLE 350 Base 4MATIC   49,548 mi.
# 15     2015 Mercedes-Benz S-Class S 550 4MATIC   57,227 mi.
# 16            2016 Mercedes-Benz E-Class E 350   48,979 mi.
# 17      2017 Mercedes-Benz GLE 350 Base 4MATIC   64,804 mi.
# 18            2018 Mercedes-Benz E-Class E 300   48,749 mi.
# 19   2014 Mercedes-Benz GL-Class GL 450 4MATIC   74,000 mi.
#
#                        Dealer_name Rating Review_count    Price
# 0              Auto Buying Service    4.8         135   $41,444
# 1       DARCARS Lexus of Greenwich    4.6          39   $32,937
# 2                Jamaica 26 Motors    3.3          28   $23,950
# 3             Bourne's Auto Center    4.9       4,180   $25,990
# 4      Mercedes-Benz of Naperville    4.6         491   $29,000
# 5                Merlex Auto Group    3.8         533   $33,499
# 6             Go Luxury Auto Group    5.0           2   $38,995
# 7         Mercedes-Benz of Ontario    4.9       1,861   $80,388
# 8                    Empire Motors    4.3          60    $9,499
# 9                    Walter's Audi    4.9       3,122   $69,911
# 10      Mercedes-Benz of Asheville    4.1          72   $62,997
# 11  Holman Honda of Ft. Lauderdale    4.7       2,086   $16,550
# 12                     AE of Miami    2.7          31    $7,450
# 13          Gravity Autos Marietta    4.0         130   $49,799
# 14         Koons Ford of Baltimore    4.8       1,549   $33,500
# 15             Auto Buying Service    4.8         135   $34,444
# 16       Autolenders Lawrenceville    4.9         478   $26,495
# 17      Jaguar Land Rover Buckhead    4.6         170   $34,900
# 18                Mazzei Chevrolet    2.6           8   $34,853
# 19           Fred's Executive Auto    4.6         384   $29,750

# %% [markdown]
# # Pagitation - Multiple pages

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range(1,50):
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+ '&page_size=20&list_price_max=&makes[]=mercedes_benz&maximum_distance=20&models[]=&stock_type=all&zip='
    
    #requesting permision
    response = requests.get(website)
    
    #soup
    soup = BeautifulSoup(response.content,'html.parser')
    
    #results
    results = soup.find_all('div',{'class':'vehicle-card'})
    
    
    
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('NA')

         #mileage
        try:
            mileage.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            mileage.append('NA')   

         #dealer_name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
        except:
            dealer_name.append('NA')  

         #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('NA')  

        #review Count
        try:
            review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
        except:
            review_count.append('NA') 

        #Price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

# %%
car_dealer
# Out:
#                                          Name     mileage  \
# 0            2016 Mercedes-Benz S-Class S 550  32,923 mi.
# 1      2019 Mercedes-Benz CLA 250 Base 4MATIC  16,532 mi.
# 2     2018 Mercedes-Benz C-Class C 300 4MATIC  42,591 mi.
# 3            2015 Mercedes-Benz C-Class C 300  35,878 mi.
# 4    2015 Mercedes-Benz M-Class ML 350 4MATIC  60,013 mi.
# ..                                        ...         ...
# 975   2019 Mercedes-Benz AMG C 43 Base 4MATIC  24,104 mi.
# 976      2014 Mercedes-Benz CLA-Class CLA 250  45,643 mi.
# 977               2018 Mercedes-Benz CLA 250   30,759 mi.
# 978    2017 Mercedes-Benz GLE 350 Base 4MATIC  63,725 mi.
# 979   2016 Mercedes-Benz S-Class S 550 4MATIC  63,522 mi.
#
#                         Dealer_name Rating Review_count    Price
# 0               Auto Buying Service    4.8         135   $41,444
# 1        DARCARS Lexus of Greenwich    4.6          39   $32,937
# 2                 Jamaica 26 Motors    3.3          28   $23,950
# 3              Bourne's Auto Center    4.9       4,180   $25,990
# 4       Mercedes-Benz of Naperville    4.6         491   $29,000
# ..                              ...    ...          ...      ...
# 975          Luxury Auto Collection    3.5          33   $69,500
# 976  Mercedes-Benz of Houston North    4.5       1,090   $21,998
# 977                 Pinnacle Nissan    3.9         635   $29,982
# 978              Selective Autoplex    4.7          53   $37,496
# 979                North State Auto    3.9          10   $69,500
#
# [980 rows x 6 columns]

# %%
split = car_dealer['Name'].str.split(' ',n=3, expand = True)
split
# Out:
#         0              1          2                 3
# 0    2016  Mercedes-Benz    S-Class             S 550
# 1    2019  Mercedes-Benz        CLA   250 Base 4MATIC
# 2    2018  Mercedes-Benz    C-Class      C 300 4MATIC
# 3    2015  Mercedes-Benz    C-Class             C 300
# 4    2015  Mercedes-Benz    M-Class     ML 350 4MATIC
# ..    ...            ...        ...               ...
# 975  2019  Mercedes-Benz        AMG  C 43 Base 4MATIC
# 976  2014  Mercedes-Benz  CLA-Class           CLA 250
# 977  2018  Mercedes-Benz        CLA              250
# 978  2017  Mercedes-Benz        GLE   350 Base 4MATIC
# 979  2016  Mercedes-Benz    S-Class      S 550 4MATIC
#
# [980 rows x 4 columns]

# %%
final = pd.concat([car_dealer, split], axis=1, join="inner")
final
# Out:
#                                          Name     mileage  \
# 0            2016 Mercedes-Benz S-Class S 550  32,923 mi.
# 1      2019 Mercedes-Benz CLA 250 Base 4MATIC  16,532 mi.
# 2     2018 Mercedes-Benz C-Class C 300 4MATIC  42,591 mi.
# 3            2015 Mercedes-Benz C-Class C 300  35,878 mi.
# 4    2015 Mercedes-Benz M-Class ML 350 4MATIC  60,013 mi.
# ..                                        ...         ...
# 975   2019 Mercedes-Benz AMG C 43 Base 4MATIC  24,104 mi.
# 976      2014 Mercedes-Benz CLA-Class CLA 250  45,643 mi.
# 977               2018 Mercedes-Benz CLA 250   30,759 mi.
# 978    2017 Mercedes-Benz GLE 350 Base 4MATIC  63,725 mi.
# 979   2016 Mercedes-Benz S-Class S 550 4MATIC  63,522 mi.
#
#                         Dealer_name Rating Review_count    Price     0  \
# 0               Auto Buying Service    4.8         135   $41,444  2016
# 1        DARCARS Lexus of Greenwich    4.6          39   $32,937  2019
# 2                 Jamaica 26 Motors    3.3          28   $23,950  2018
# 3              Bourne's Auto Center    4.9       4,180   $25,990  2015
# 4       Mercedes-Benz of Naperville    4.6         491   $29,000  2015
# ..                              ...    ...          ...      ...   ...
# 975          Luxury Auto Collection    3.5          33   $69,500  2019
# 976  Mercedes-Benz of Houston North    4.5       1,090   $21,998  2014
# 977                 Pinnacle Nissan    3.9         635   $29,982  2018
# 978              Selective Autoplex    4.7          53   $37,496  2017
# 979                North State Auto    3.9          10   $69,500  2016
#
#                  1          2                 3
# 0    Mercedes-Benz    S-Class             S 550
# 1    Mercedes-Benz        CLA   250 Base 4MATIC
# 2    Mercedes-Benz    C-Class      C 300 4MATIC
# 3    Mercedes-Benz    C-Class             C 300
# 4    Mercedes-Benz    M-Class     ML 350 4MATIC
# ..             ...        ...               ...
# 975  Mercedes-Benz        AMG  C 43 Base 4MATIC
# 976  Mercedes-Benz  CLA-Class           CLA 250
# 977  Mercedes-Benz        CLA              250
# 978  Mercedes-Benz        GLE   350 Base 4MATIC
# 979  Mercedes-Benz    S-Class      S 550 4MATIC
#
# [980 rows x 10 columns]

# %%
final.to_excel('Mercedez_new_all.xlsx', index=True)

# %% [markdown]
# # Cars.com KIA

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=used&makes%5B%5D=kia&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %%
response = requests.get(website)
response.status_code
soup = BeautifulSoup(response.content,'html.parser')
results = soup.find_all('div',{'class':'vehicle-card'})

# %%
len(results)
# Out:
# 20

# %%
#Name of car
results[0].find('h2')
results[0].find('h2').get_text() #Just to get only the text

#Km it has run
results[0].find('div',{'class':'mileage'})
results[0].find('div',{'class':'mileage'}).get_text()

#RAting
results[0].find('span',{'class':'sds-rating__count'})
results[0].find('span',{'class':'sds-rating__count'}).get_text()

#Number of Rating
results[0].find('span',{'class':'sds-rating__link sds-button-link'})
results[0].find('span',{'class':'sds-rating__link sds-button-link'}).get_text()

#Price
results[0].find('span',{'class':'primary-price'})
results[0].find('span',{'class':'primary-price'}).get_text()

#Dealer
results[0].find('div',{'class':'dealer-name'})
results[0].find('div',{'class':'dealer-name'}).get_text()
# Out:
# '\nHawkinson Kia\n'

# %%
#Putting all together
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('NA')
        
     #mileage
    try:
        mileage.append(result.find('div',{'class':'mileage'}).get_text())
    except:
        mileage.append('NA')   
        
     #dealer_name
    try:
        dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
    except:
        dealer_name.append('NA')  
        
     #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('NA')  
        
    #review Count
    try:
        review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
    except:
        review_count.append('NA') 
        
    #Price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                         Name      mileage  \
# 0       2022 Kia Stinger GT2   12,005 mi.
# 1      2020 Kia Telluride SX   13,992 mi.
# 2     2020 Kia Sorento LX V6   46,267 mi.
# 3      2020 Kia Telluride SX   28,125 mi.
# 4      2020 Kia Telluride SX   39,200 mi.
# 5         2021 Kia Sedona EX   25,278 mi.
# 6       2020 Kia Sportage LX   43,231 mi.
# 7      2021 Kia Telluride SX   14,025 mi.
# 8   2021 Kia Stinger GT-Line   17,634 mi.
# 9         2021 Kia Sedona EX   23,742 mi.
# 10        2020 Kia Forte LXS   14,599 mi.
# 11      2018 Kia Stinger GT2   42,874 mi.
# 12       2018 Kia Sorento LX   25,200 mi.
# 13      2020 Kia Sportage EX   17,794 mi.
# 14     2021 Kia Telluride EX   11,831 mi.
# 15           2010 Kia Soul +  139,702 mi.
# 16     2020 Kia Telluride SX   37,806 mi.
# 17     2020 Kia Telluride SX   35,715 mi.
# 18  2014 Kia Sorento Limited   95,808 mi.
# 19       2020 Kia Sorento LX    9,938 mi.
#
#                                        Dealer_name Rating Review_count  \
# 0                                    Hawkinson Kia    4.3         119
# 1                                   Feretti Motors    4.0          25
# 2   EchoPark Automotive Greenville Delivery Center    4.4          19
# 3                        Carriage Kia of Woodstock    4.8         521
# 4                         Koons Woodbridge Hyundai    4.1          28
# 5                                   Walser Hyundai    4.9       1,570
# 6                    Summit Place Kia Auburn Hills    4.9       1,911
# 7                          Ricart Used Car Factory    4.7       5,191
# 8                             The Internet Car Lot    3.8         269
# 9                                   Walser Hyundai    4.9       1,570
# 10                           All in One Auto Group    3.8          25
# 11                                APX Auto Brokers    5.0           1
# 12                      EchoPark Automotive Dallas    4.8       4,156
# 13                          Toyota of Lincoln Park    4.2         218
# 14                               AutoSavvy Windsor    4.2         170
# 15                                   Empire Motors    4.3          60
# 16                                   Ed Voyles Kia    4.3          32
# 17                       Southern Pines Nissan Kia    3.9          36
# 18                              Greenville Hyundai    4.4         250
# 19                                Garden Grove Kia    4.6         844
#
#       Price
# 0   $49,000
# 1   $41,500
# 2   $24,739
# 3   $52,192
# 4   $47,900
# 5   $30,998
# 6   $24,777
# 7   $56,779
# 8   $34,495
# 9   $30,998
# 10  $16,995
# 11  $39,991
# 12  $23,889
# 13  $30,809
# 14  $43,400
# 15   $4,999
# 16  $53,955
# 17  $50,998
# 18  $12,900
# 19  $31,838

# %% [markdown]
# # Pagitation for KIA

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range(1,50):
    website = 'https://www.cars.com/shopping/results/?page=' + str(i) + '5&page_size=20&list_price_max=&makes[]=kia&maximum_distance=20&models[]=&stock_type=used&zip='
    
    #requesting permision
    response = requests.get(website)
    
    #soup
    soup = BeautifulSoup(response.content,'html.parser')
    
    #results
    results = soup.find_all('div',{'class':'vehicle-card'})
    
    
    
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('NA')

         #mileage
        try:
            mileage.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            mileage.append('NA')   

         #dealer_name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
        except:
            dealer_name.append('NA')  

         #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('NA')  

        #review Count
        try:
            review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
        except:
            review_count.append('NA') 

        #Price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                        Name      mileage  \
# 0        2019 Kia Forte LXS   18,659 mi.
# 1       2016 Kia Sorento LX   69,349 mi.
# 2       2021 Kia K5 GT-Line   11,842 mi.
# 3       2019 Kia Sorento LX   45,033 mi.
# 4      2021 Kia Telluride S   17,934 mi.
# ..                      ...          ...
# 974      2020 Kia Optima LX   45,015 mi.
# 975      2015 Kia Optima LX   86,655 mi.
# 976      2016 Kia Optima LX   83,501 mi.
# 977  2020 Kia Sorento LX V6    9,612 mi.
# 978      2015 Kia Optima LX  119,238 mi.
#
#                                            Dealer_name Rating Review_count  \
# 0                            Matt Blatt Toms River Kia    4.7         582
# 1                 Edwards Chevrolet Buick GMC Cadillac    4.7         251
# 2                                    Classic Chevrolet    3.9         185
# 3                                 Dave White Chevrolet    4.7       1,308
# 4                                         Courtesy Kia    4.5         579
# ..                                                 ...    ...          ...
# 974                         AutoNation INFINITI Tustin    4.6         505
# 975  Anderson Ford Lincoln Kia Mitsubishi of St. Jo...    4.7         484
# 976                         Corwin Ford of Springfield    4.6         649
# 977                                           Team Kia    4.8          79
# 978                                   Miller Chevrolet    4.8         548
#
#        Price
# 0    $21,993
# 1    $18,950
# 2    $33,000
# 3    $25,902
# 4    $46,899
# ..       ...
# 974  $22,195
# 975  $15,286
# 976  $15,990
# 977  $33,990
# 978  $11,990
#
# [979 rows x 6 columns]

# %%
split = car_dealer['Name'].str.split(' ',n=3, expand = True)
split
# Out:
#         0    1          2        3
# 0    2019  Kia      Forte      LXS
# 1    2016  Kia    Sorento       LX
# 2    2021  Kia         K5  GT-Line
# 3    2019  Kia    Sorento       LX
# 4    2021  Kia  Telluride        S
# ..    ...  ...        ...      ...
# 974  2020  Kia     Optima       LX
# 975  2015  Kia     Optima       LX
# 976  2016  Kia     Optima       LX
# 977  2020  Kia    Sorento    LX V6
# 978  2015  Kia     Optima       LX
#
# [979 rows x 4 columns]

# %%
final = pd.concat([car_dealer, split], axis=1, join="inner")
final
# Out:
#                        Name      mileage  \
# 0        2019 Kia Forte LXS   18,659 mi.
# 1       2016 Kia Sorento LX   69,349 mi.
# 2       2021 Kia K5 GT-Line   11,842 mi.
# 3       2019 Kia Sorento LX   45,033 mi.
# 4      2021 Kia Telluride S   17,934 mi.
# ..                      ...          ...
# 974      2020 Kia Optima LX   45,015 mi.
# 975      2015 Kia Optima LX   86,655 mi.
# 976      2016 Kia Optima LX   83,501 mi.
# 977  2020 Kia Sorento LX V6    9,612 mi.
# 978      2015 Kia Optima LX  119,238 mi.
#
#                                            Dealer_name Rating Review_count  \
# 0                            Matt Blatt Toms River Kia    4.7         582
# 1                 Edwards Chevrolet Buick GMC Cadillac    4.7         251
# 2                                    Classic Chevrolet    3.9         185
# 3                                 Dave White Chevrolet    4.7       1,308
# 4                                         Courtesy Kia    4.5         579
# ..                                                 ...    ...          ...
# 974                         AutoNation INFINITI Tustin    4.6         505
# 975  Anderson Ford Lincoln Kia Mitsubishi of St. Jo...    4.7         484
# 976                         Corwin Ford of Springfield    4.6         649
# 977                                           Team Kia    4.8          79
# 978                                   Miller Chevrolet    4.8         548
#
#        Price     0    1          2        3
# 0    $21,993  2019  Kia      Forte      LXS
# 1    $18,950  2016  Kia    Sorento       LX
# 2    $33,000  2021  Kia         K5  GT-Line
# 3    $25,902  2019  Kia    Sorento       LX
# 4    $46,899  2021  Kia  Telluride        S
# ..       ...   ...  ...        ...      ...
# 974  $22,195  2020  Kia     Optima       LX
# 975  $15,286  2015  Kia     Optima       LX
# 976  $15,990  2016  Kia     Optima       LX
# 977  $33,990  2020  Kia    Sorento    LX V6
# 978  $11,990  2015  Kia     Optima       LX
#
# [979 rows x 10 columns]

# %%
final.to_excel('Kia_all.xlsx', index=True)

# %% [markdown]
# # Cars.com TOYOTA

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=used&makes%5B%5D=toyota&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %%
response = requests.get(website)
response.status_code
soup = BeautifulSoup(response.content,'html.parser')
results = soup.find_all('div',{'class':'vehicle-card'})

# %%
len(results)
# Out:
# 20

# %%
#Name of car
results[0].find('h2')
results[0].find('h2').get_text() #Just to get only the text

#Km it has run
results[0].find('div',{'class':'mileage'})
results[0].find('div',{'class':'mileage'}).get_text()

#RAting
results[0].find('span',{'class':'sds-rating__count'})
results[0].find('span',{'class':'sds-rating__count'}).get_text()

#Number of Rating
results[0].find('span',{'class':'sds-rating__link sds-button-link'})
results[0].find('span',{'class':'sds-rating__link sds-button-link'}).get_text()

#Price
results[0].find('span',{'class':'primary-price'})
results[0].find('span',{'class':'primary-price'}).get_text()

#Dealer
results[0].find('div',{'class':'dealer-name'})
results[0].find('div',{'class':'dealer-name'}).get_text()
# Out:
# '\nKoons Tysons Toyota\n'

# %%
#Putting all together
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('NA')
        
     #mileage
    try:
        mileage.append(result.find('div',{'class':'mileage'}).get_text())
    except:
        mileage.append('NA')   
        
     #dealer_name
    try:
        dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
    except:
        dealer_name.append('NA')  
        
     #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('NA')  
        
    #review Count
    try:
        review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
    except:
        review_count.append('NA') 
        
    #Price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                        Name     mileage  \
# 0               2018 Toyota 4Runner Limited  45,650 mi.
# 1               2013 Toyota Land Cruiser V8  13,430 mi.
# 2                    2016 Toyota Tacoma SR5  68,814 mi.
# 3                     2019 Toyota Camry XSE  13,313 mi.
# 4              2019 Toyota Sequoia Platinum  55,121 mi.
# 5            2017 Toyota Highlander Limited  84,621 mi.
# 6                    2019 Toyota Tundra SR5  23,840 mi.
# 7              2019 Toyota Sequoia Platinum  54,668 mi.
# 8   2016 Toyota Highlander Limited Platinum  62,598 mi.
# 9                      2021 Toyota Camry SE  19,288 mi.
# 10                    2019 Toyota Camry XSE  18,142 mi.
# 11              2016 Toyota 4Runner Limited  80,825 mi.
# 12                    2021 Toyota Supra 3.0   4,121 mi.
# 13                   2019 Toyota Tundra SR5  21,338 mi.
# 14                   2018 Toyota Tacoma SR5  14,577 mi.
# 15              2020 Toyota Tundra Platinum  14,789 mi.
# 16           2021 Toyota Highlander Limited   5,136 mi.
# 17               2014 Toyota Highlander XLE  48,367 mi.
# 18                   2018 Toyota Tundra SR5  15,757 mi.
# 19                     2019 Toyota Camry LE  47,205 mi.
#
#                                       Dealer_name Rating Review_count    Price
# 0                             Koons Tysons Toyota    4.4       1,330   $41,800
# 1                      Koons of Falls Church Ford    4.3         866   $61,000
# 2                                 Westshore Mazda    4.0          36   $29,229
# 3                                 Arrowhead Lexus    4.7          95   $35,490
# 4                               Texas Direct Auto    4.5       2,092   $51,999
# 5                North Park Toyota of San Antonio    4.9       1,745   $30,981
# 6                            Toyota of Brookfield    4.7       1,294   $46,090
# 7                               Texas Direct Auto    4.5       2,092   $57,999
# 8                        AutoNation Toyota Weston    4.7       1,892   $29,446
# 9                         Fort Wayne Toyota Lexus    4.5         656   $31,125
# 10                          Tansky Sawmill Toyota    4.6         762   $31,766
# 11                           Ganley Parma Hyundai    4.8         784   $32,797
# 12                       Koons Woodbridge Hyundai    4.1          28   $56,500
# 13                     Crain Ford of Jacksonville    4.5         312   $38,200
# 14                         Toyota of Cool Springs    4.7       1,114   $35,985
# 15                              Alexandria Motors    4.8         172   $55,990
# 16             Mike Anderson Chevrolet of Chicago    4.5         341   $50,995
# 17                            Bozard Ford Lincoln    4.9       7,509   $24,992
# 18                 Marion Chrysler Dodge Jeep Ram    4.8          88   $42,500
# 19  EchoPark Automotive Houston Southwest Freeway    4.9          46   $23,169

# %% [markdown]
# # Pagitation for TOYOTA

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range(1,70):
    website = 'https://www.cars.com/shopping/results/?page=' + str(i) + '4&page_size=20&list_price_max=&makes[]=toyota&maximum_distance=20&models[]=&stock_type=used&zip='
    
    #requesting permision
    response = requests.get(website)
    
    #soup
    soup = BeautifulSoup(response.content,'html.parser')
    
    #results
    results = soup.find_all('div',{'class':'vehicle-card'})
    
    
    
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('NA')

         #mileage
        try:
            mileage.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            mileage.append('NA')   

         #dealer_name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
        except:
            dealer_name.append('NA')  

         #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('NA')  

        #review Count
        try:
            review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
        except:
            review_count.append('NA') 

        #Price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                           Name     mileage  \
# 0                  2019 Toyota 4Runner Limited  48,642 mi.
# 1                   2020 Toyota RAV4 Adventure  25,001 mi.
# 2                        2019 Toyota Camry XSE  48,823 mi.
# 3                          2018 Toyota RAV4 LE  41,826 mi.
# 4                        2019 Toyota Camry XSE  19,347 mi.
# ...                                        ...         ...
# 1373  2021 Toyota 4Runner TRD Off Road Premium  23,715 mi.
# 1374                2015 Toyota Highlander XLE  82,715 mi.
# 1375                 2019 Toyota Highlander LE  25,728 mi.
# 1376                2018 Toyota Highlander XLE  33,535 mi.
# 1377                      2019 Toyota RAV4 XLE  20,850 mi.
#
#                      Dealer_name Rating Review_count    Price
# 0      Mid-State Chevrolet Buick    4.3          33   $49,158
# 1     Merchants Automotive Group    4.8       2,419   $33,704
# 2         Land Rover San Antonio    3.8          71   $31,500
# 3                 Landers Toyota    4.9       2,290   $25,695
# 4          Nalley Lexus, Roswell    4.6         593   $33,199
# ...                          ...    ...          ...      ...
# 1373              Wholesale Inc.    4.7         401   $51,394
# 1374            Andy Mohr Toyota    4.4         758   $28,000
# 1375  AutoNation Chevrolet Doral    4.6         417   $33,999
# 1376         East Madison Toyota    4.7       1,120   $34,506
# 1377   Prestige Toyota of Ramsey    4.6       2,591   $34,195
#
# [1378 rows x 6 columns]

# %%
split = car_dealer['Name'].str.split(' ',n=3, expand = True)
split
# Out:
#          0       1           2                     3
# 0     2019  Toyota     4Runner               Limited
# 1     2020  Toyota        RAV4             Adventure
# 2     2019  Toyota       Camry                   XSE
# 3     2018  Toyota        RAV4                    LE
# 4     2019  Toyota       Camry                   XSE
# ...    ...     ...         ...                   ...
# 1373  2021  Toyota     4Runner  TRD Off Road Premium
# 1374  2015  Toyota  Highlander                   XLE
# 1375  2019  Toyota  Highlander                    LE
# 1376  2018  Toyota  Highlander                   XLE
# 1377  2019  Toyota        RAV4                   XLE
#
# [1378 rows x 4 columns]

# %%
final = pd.concat([car_dealer, split], axis=1, join="inner")
final
# Out:
#                                           Name     mileage  \
# 0                  2019 Toyota 4Runner Limited  48,642 mi.
# 1                   2020 Toyota RAV4 Adventure  25,001 mi.
# 2                        2019 Toyota Camry XSE  48,823 mi.
# 3                          2018 Toyota RAV4 LE  41,826 mi.
# 4                        2019 Toyota Camry XSE  19,347 mi.
# ...                                        ...         ...
# 1373  2021 Toyota 4Runner TRD Off Road Premium  23,715 mi.
# 1374                2015 Toyota Highlander XLE  82,715 mi.
# 1375                 2019 Toyota Highlander LE  25,728 mi.
# 1376                2018 Toyota Highlander XLE  33,535 mi.
# 1377                      2019 Toyota RAV4 XLE  20,850 mi.
#
#                      Dealer_name Rating Review_count    Price     0       1  \
# 0      Mid-State Chevrolet Buick    4.3          33   $49,158  2019  Toyota
# 1     Merchants Automotive Group    4.8       2,419   $33,704  2020  Toyota
# 2         Land Rover San Antonio    3.8          71   $31,500  2019  Toyota
# 3                 Landers Toyota    4.9       2,290   $25,695  2018  Toyota
# 4          Nalley Lexus, Roswell    4.6         593   $33,199  2019  Toyota
# ...                          ...    ...          ...      ...   ...     ...
# 1373              Wholesale Inc.    4.7         401   $51,394  2021  Toyota
# 1374            Andy Mohr Toyota    4.4         758   $28,000  2015  Toyota
# 1375  AutoNation Chevrolet Doral    4.6         417   $33,999  2019  Toyota
# 1376         East Madison Toyota    4.7       1,120   $34,506  2018  Toyota
# 1377   Prestige Toyota of Ramsey    4.6       2,591   $34,195  2019  Toyota
#
#                2                     3
# 0        4Runner               Limited
# 1           RAV4             Adventure
# 2          Camry                   XSE
# 3           RAV4                    LE
# 4          Camry                   XSE
# ...          ...                   ...
# 1373     4Runner  TRD Off Road Premium
# 1374  Highlander                   XLE
# 1375  Highlander                    LE
# 1376  Highlander                   XLE
# 1377        RAV4                   XLE
#
# [1378 rows x 10 columns]

# %%
final.to_excel('Toyota_all.xlsx', index=True)

# %% [markdown]
# # Cars.com AUDI

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=used&makes%5B%5D=audi&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %%
response = requests.get(website)
response.status_code
soup = BeautifulSoup(response.content,'html.parser')
results = soup.find_all('div',{'class':'vehicle-card'})

# %%
len(results)
# Out:
# 20

# %%
#Name of car
results[0].find('h2')
results[0].find('h2').get_text() #Just to get only the text

#Km it has run
results[0].find('div',{'class':'mileage'})
results[0].find('div',{'class':'mileage'}).get_text()

#RAting
results[0].find('span',{'class':'sds-rating__count'})
results[0].find('span',{'class':'sds-rating__count'}).get_text()

#Number of Rating
results[0].find('span',{'class':'sds-rating__link sds-button-link'})
results[0].find('span',{'class':'sds-rating__link sds-button-link'}).get_text()

#Price
results[0].find('span',{'class':'primary-price'})
results[0].find('span',{'class':'primary-price'}).get_text()

#Dealer
results[0].find('div',{'class':'dealer-name'})
results[0].find('div',{'class':'dealer-name'}).get_text()
# Out:
# '\nAudi Nashville\n'

# %%
#Putting all together
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('NA')
        
     #mileage
    try:
        mileage.append(result.find('div',{'class':'mileage'}).get_text())
    except:
        mileage.append('NA')   
        
     #dealer_name
    try:
        dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
    except:
        dealer_name.append('NA')  
        
     #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('NA')  
        
    #review Count
    try:
        review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
    except:
        review_count.append('NA') 
        
    #Price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                       Name      mileage  \
# 0                2018 Audi A5 2.0T Premium   26,798 mi.
# 1           2016 Audi A6 3.0T Premium Plus   69,704 mi.
# 2           2018 Audi Q5 2.0T Premium Plus   22,000 mi.
# 3           2018 Audi S6 4.0T Premium Plus   14,701 mi.
# 4   2013 Audi S5 3.0T Premium Plus quattro   47,954 mi.
# 5                  2021 Audi Q3 40 Premium    6,403 mi.
# 6                2019 Audi A4 2.0T Premium   21,528 mi.
# 7           2011 Audi A5 2.0T Premium Plus   80,564 mi.
# 8                2019 Audi A5 2.0T Premium   68,050 mi.
# 9   2013 Audi S5 3.0T Premium Plus quattro   79,672 mi.
# 10               2018 Audi A3 2.0T Premium    7,816 mi.
# 11          2016 Audi A6 3.0T Premium Plus   52,485 mi.
# 12              2018 Audi Q5 2.0T Prestige   53,342 mi.
# 13               2019 Audi A3 2.0T Premium   20,783 mi.
# 14              2019 Audi A7 3.0T Prestige   14,650 mi.
# 15              2019 Audi A5 2.0T Prestige   17,298 mi.
# 16         2018 Audi A4 2.0T ultra Premium   22,550 mi.
# 17               2018 Audi A3 2.0T Premium   12,892 mi.
# 18            2014 Audi RS 7 4.0T Prestige   23,025 mi.
# 19           2012 Audi Q5 3.2 Premium Plus  208,684 mi.
#
#                                       Dealer_name Rating Review_count    Price
# 0                                  Audi Nashville    4.6         429   $37,997
# 1                             Autobahn USA Dedham    4.5         969   $24,988
# 2                                    Autohaus Inc    4.7          70   $29,900
# 3                      DARCARS Lexus of Greenwich    4.6          39   $56,372
# 4                                 Landmark Motors    4.6         120   $28,998
# 5                                     Audi Peoria    4.7         423   $34,977
# 6                                   Prestman Auto    4.2         448   $28,000
# 7                            Brightway Auto Sales    4.3          37   $15,900
# 8                           CarLotz Downers Grove    4.7         225   $31,998
# 9                          International Autohaus    3.4           7   $24,999
# 10                           INFINITI of Suitland    4.5         135   $39,015
# 11                             Toyota of Gastonia    4.6         584   $28,699
# 12                                  Audi Westmont    4.6         879   $37,710
# 13                   STG Auto Group of Bellflower    4.4           7   $30,288
# 14                              Audi Owings Mills    4.8         198   $71,989
# 15                            Fletcher Jones Audi    4.8       1,060   $43,911
# 16                             Audi Beverly Hills    4.9       2,011   $29,493
# 17  EchoPark Automotive Houston Southwest Freeway    4.9          46   $29,479
# 18                            Auto Buying Service    4.8         135   $60,444
# 19       Steve White Volkswagen Audi - Greenville    4.8         905    $9,995

# %% [markdown]
# # Pagitation for AUDI

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range(1,70):
    website = 'https://www.cars.com/shopping/results/?page=' + str(i) + '4&page_size=20&list_price_max=&makes[]=audi&maximum_distance=20&models[]=&stock_type=used&zip='
    
    #requesting permision
    response = requests.get(website)
    
    #soup
    soup = BeautifulSoup(response.content,'html.parser')
    
    #results
    results = soup.find_all('div',{'class':'vehicle-card'})
    
    
    
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('NA')

         #mileage
        try:
            mileage.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            mileage.append('NA')   

         #dealer_name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
        except:
            dealer_name.append('NA')  

         #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('NA')  

        #review Count
        try:
            review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
        except:
            review_count.append('NA') 

        #Price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                     Name      mileage  \
# 0        2018 Audi SQ5 3.0T Premium Plus   29,451 mi.
# 1              2012 Audi Q5 2.0T Premium   41,258 mi.
# 2             2018 Audi Q5 2.0T Prestige   57,645 mi.
# 3         2018 Audi Q7 3.0T Premium Plus   35,177 mi.
# 4             2018 Audi Q5 2.0T Prestige   49,695 mi.
# ...                                  ...          ...
# 1372           2019 Audi A3 2.0T Premium   15,412 mi.
# 1373       2010 Audi Q5 3.2 Premium Plus  148,988 mi.
# 1374      2014 Audi A5 2.0T Premium Plus   67,797 mi.
# 1375  2014 Audi S7 4.0T Prestige quattro   78,875 mi.
# 1376                2019 Audi A6 Premium   25,202 mi.
#
#                     Dealer_name Rating Review_count    Price
# 0                 Lynnes Nissan    4.0         394   $43,200
# 1               Glendale Nissan    3.6         218   $19,990
# 2                Audi Grapevine    4.6         776   $37,400
# 3              Audi Minneapolis    4.8       1,079   $45,990
# 4                    Laurel Kia    4.8         749   $38,788
# ...                         ...    ...          ...      ...
# 1372              Brandon Dodge    4.8       2,045   $32,472
# 1373     Frontline Auto Brokers    4.7         269   $11,995
# 1374  Napleton River Oaks Honda    4.7       1,506   $19,500
# 1375       Sears Imported Autos    4.9       1,720   $36,495
# 1376          Audi West Houston    4.7         549   $46,996
#
# [1377 rows x 6 columns]

# %%
split = car_dealer['Name'].str.split(' ',n=3, expand = True)
split
# Out:
#          0     1    2                      3
# 0     2018  Audi  SQ5      3.0T Premium Plus
# 1     2012  Audi   Q5           2.0T Premium
# 2     2018  Audi   Q5          2.0T Prestige
# 3     2018  Audi   Q7      3.0T Premium Plus
# 4     2018  Audi   Q5          2.0T Prestige
# ...    ...   ...  ...                    ...
# 1372  2019  Audi   A3           2.0T Premium
# 1373  2010  Audi   Q5       3.2 Premium Plus
# 1374  2014  Audi   A5      2.0T Premium Plus
# 1375  2014  Audi   S7  4.0T Prestige quattro
# 1376  2019  Audi   A6                Premium
#
# [1377 rows x 4 columns]

# %%
final = pd.concat([car_dealer, split], axis=1, join="inner")
final
# Out:
#                                     Name      mileage  \
# 0        2018 Audi SQ5 3.0T Premium Plus   29,451 mi.
# 1              2012 Audi Q5 2.0T Premium   41,258 mi.
# 2             2018 Audi Q5 2.0T Prestige   57,645 mi.
# 3         2018 Audi Q7 3.0T Premium Plus   35,177 mi.
# 4             2018 Audi Q5 2.0T Prestige   49,695 mi.
# ...                                  ...          ...
# 1372           2019 Audi A3 2.0T Premium   15,412 mi.
# 1373       2010 Audi Q5 3.2 Premium Plus  148,988 mi.
# 1374      2014 Audi A5 2.0T Premium Plus   67,797 mi.
# 1375  2014 Audi S7 4.0T Prestige quattro   78,875 mi.
# 1376                2019 Audi A6 Premium   25,202 mi.
#
#                     Dealer_name Rating Review_count    Price     0     1    2  \
# 0                 Lynnes Nissan    4.0         394   $43,200  2018  Audi  SQ5
# 1               Glendale Nissan    3.6         218   $19,990  2012  Audi   Q5
# 2                Audi Grapevine    4.6         776   $37,400  2018  Audi   Q5
# 3              Audi Minneapolis    4.8       1,079   $45,990  2018  Audi   Q7
# 4                    Laurel Kia    4.8         749   $38,788  2018  Audi   Q5
# ...                         ...    ...          ...      ...   ...   ...  ...
# 1372              Brandon Dodge    4.8       2,045   $32,472  2019  Audi   A3
# 1373     Frontline Auto Brokers    4.7         269   $11,995  2010  Audi   Q5
# 1374  Napleton River Oaks Honda    4.7       1,506   $19,500  2014  Audi   A5
# 1375       Sears Imported Autos    4.9       1,720   $36,495  2014  Audi   S7
# 1376          Audi West Houston    4.7         549   $46,996  2019  Audi   A6
#
#                           3
# 0         3.0T Premium Plus
# 1              2.0T Premium
# 2             2.0T Prestige
# 3         3.0T Premium Plus
# 4             2.0T Prestige
# ...                     ...
# 1372           2.0T Premium
# 1373       3.2 Premium Plus
# 1374      2.0T Premium Plus
# 1375  4.0T Prestige quattro
# 1376                Premium
#
# [1377 rows x 10 columns]

# %%
final.to_excel('Audi_all.xlsx', index=True)

# %% [markdown]
# # Cars.com Porsche

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=used&makes%5B%5D=porsche&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %%
response = requests.get(website)
response.status_code
soup = BeautifulSoup(response.content,'html.parser')
results = soup.find_all('div',{'class':'vehicle-card'})

# %%
#Name of car
results[0].find('h2')
results[0].find('h2').get_text() #Just to get only the text

#Km it has run
results[0].find('div',{'class':'mileage'})
results[0].find('div',{'class':'mileage'}).get_text()

#RAting
results[0].find('span',{'class':'sds-rating__count'})
results[0].find('span',{'class':'sds-rating__count'}).get_text()

#Number of Rating
results[0].find('span',{'class':'sds-rating__link sds-button-link'})
results[0].find('span',{'class':'sds-rating__link sds-button-link'}).get_text()

#Price
results[0].find('span',{'class':'primary-price'})
results[0].find('span',{'class':'primary-price'}).get_text()

#Dealer
results[0].find('div',{'class':'dealer-name'})
results[0].find('div',{'class':'dealer-name'}).get_text()
# Out:
# '\nAutoNation Chevrolet Airport\n'

# %%
#Putting all together
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('NA')
        
     #mileage
    try:
        mileage.append(result.find('div',{'class':'mileage'}).get_text())
    except:
        mileage.append('NA')   
        
     #dealer_name
    try:
        dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
    except:
        dealer_name.append('NA')  
        
     #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('NA')  
        
    #review Count
    try:
        review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
    except:
        review_count.append('NA') 
        
    #Price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                      Name     mileage  \
# 0                2014 Porsche Cayenne GTS  78,821 mi.
# 1              2012 Porsche 911 Carrera S  59,364 mi.
# 2                2014 Porsche Cayman Base  67,499 mi.
# 3                    2016 Porsche Macan S  37,901 mi.
# 4                 2018 Porsche Panamera 4  38,242 mi.
# 5              2012 Porsche 911 Carrera S  45,004 mi.
# 6                    2018 Porsche Macan S  28,274 mi.
# 7                    2017 Porsche Macan S  54,224 mi.
# 8   2017 Porsche Cayenne Platinum Edition  19,051 mi.
# 9                    2018 Porsche Macan S  12,216 mi.
# 10              2019 Porsche Cayenne Base  31,862 mi.
# 11                   2015 Porsche Macan S  51,165 mi.
# 12                 2018 Porsche 911 Turbo  19,006 mi.
# 13              2013 Porsche Panamera GTS  35,230 mi.
# 14                   2016 Porsche Macan S  67,159 mi.
# 15                   2015 Porsche Macan S  89,528 mi.
# 16             2018 Porsche Panamera Base  21,488 mi.
# 17            2020 Porsche 911 Carrera 4S   9,179 mi.
# 18                   2019 Porsche Macan S  11,780 mi.
# 19                   2015 Porsche Macan S  49,425 mi.
#
#                         Dealer_name Rating Review_count     Price
# 0      AutoNation Chevrolet Airport    4.7         511    $39,992
# 1    Mercedes-Benz of Houston North    4.5       1,090    $71,998
# 2   Balise Honda of North Attleboro    4.6         367    $39,977
# 3               Shift San Francisco    3.7         126    $43,250
# 4            Cadillac of Naperville    4.3         211    $73,995
# 5              Porsche West Houston    4.6         547    $79,999
# 6                       AE of Miami    2.7          31    $21,000
# 7                 Porsche Chantilly    4.7          62    $44,490
# 8                   Bernardi Toyota    4.6       1,036    $56,989
# 9              The Porsche Exchange    4.6         153    $62,995
# 10        AutoNation Toyota Hayward    4.4         744    $70,955
# 11                    Selden Motors    3.8          95    $39,900
# 12                   Porsche Austin    4.1         141   $182,557
# 13                          eCarOne    4.8       1,716    $52,950
# 14           Cadillac of Naperville    4.3         211    $39,995
# 15        Florida Fine Cars Margate    4.9         698    $32,999
# 16             Porsche West Houston    4.6         547    $82,999
# 17             The Porsche Exchange    4.6         153   $171,995
# 18                Porsche Arlington    4.6         768    $64,977
# 19       Motorcars of the Main Line    4.9         130    $42,950

# %% [markdown]
# # Pagitation for porsche cars

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range(1,70):
    website = 'https://www.cars.com/shopping/results/?page=' + str(i) + '4&page_size=20&list_price_max=&makes[]=porsche&maximum_distance=20&models[]=&stock_type=used&zip='
    
    #requesting permision
    response = requests.get(website)
    
    #soup
    soup = BeautifulSoup(response.content,'html.parser')
    
    #results
    results = soup.find_all('div',{'class':'vehicle-card'})
    
    
    
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('NA')

         #mileage
        try:
            mileage.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            mileage.append('NA')   

         #dealer_name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
        except:
            dealer_name.append('NA')  

         #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('NA')  

        #review Count
        try:
            review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
        except:
            review_count.append('NA') 

        #Price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                     Name     mileage  \
# 0                 2018 Porsche Macan GTS  36,698 mi.
# 1              2019 Porsche Cayenne Base  19,008 mi.
# 2               2016 Porsche 911 Turbo S  22,170 mi.
# 3                   2016 Porsche Macan S  79,441 mi.
# 4                2018 Porsche Macan Base  23,868 mi.
# ...                                  ...         ...
# 1373                  1973 Porsche 911 S       0 mi.
# 1374                  1969 Porsche 911 E       0 mi.
# 1375                 1980 Porsche 911 SC       0 mi.
# 1376                 1978 Porsche 911 SC       0 mi.
# 1377  1997 Porsche 911 Carrera Cabriolet       0 mi.
#
#                                             Dealer_name Rating Review_count  \
# 0                               CarShop South Brunswick    4.9          24
# 1                                      Champion Porsche    3.6          97
# 2                                         Porsche Plano    4.8       1,078
# 3     Vroom - Get It Delivered Nationwide, Contact-Free    3.7       6,649
# 4                                Gravity Autos Marietta    4.0         130
# ...                                                 ...    ...          ...
# 1373                          Gullwing Motor Cars, Inc.     NA           NA
# 1374                             Beverly Hills Car Club     NA           NA
# 1375                             Beverly Hills Car Club     NA           NA
# 1376                             Beverly Hills Car Club     NA           NA
# 1377                             Beverly Hills Car Club     NA           NA
#
#          Price
# 0      $63,999
# 1      $71,900
# 2     $164,995
# 3      $33,999
# 4      $49,998
# ...        ...
# 1373  $129,500
# 1374   $46,500
# 1375   $54,500
# 1376   $59,950
# 1377   $58,500
#
# [1378 rows x 6 columns]

# %%
split = car_dealer['Name'].str.split(' ',n=3, expand = True)
split
# Out:
#          0        1        2                  3
# 0     2018  Porsche    Macan                GTS
# 1     2019  Porsche  Cayenne               Base
# 2     2016  Porsche      911            Turbo S
# 3     2016  Porsche    Macan                  S
# 4     2018  Porsche    Macan               Base
# ...    ...      ...      ...                ...
# 1373  1973  Porsche      911                  S
# 1374  1969  Porsche      911                  E
# 1375  1980  Porsche      911                 SC
# 1376  1978  Porsche      911                 SC
# 1377  1997  Porsche      911  Carrera Cabriolet
#
# [1378 rows x 4 columns]

# %%
final = pd.concat([car_dealer, split], axis=1, join="inner")
final
# Out:
#                                     Name     mileage  \
# 0                 2018 Porsche Macan GTS  36,698 mi.
# 1              2019 Porsche Cayenne Base  19,008 mi.
# 2               2016 Porsche 911 Turbo S  22,170 mi.
# 3                   2016 Porsche Macan S  79,441 mi.
# 4                2018 Porsche Macan Base  23,868 mi.
# ...                                  ...         ...
# 1373                  1973 Porsche 911 S       0 mi.
# 1374                  1969 Porsche 911 E       0 mi.
# 1375                 1980 Porsche 911 SC       0 mi.
# 1376                 1978 Porsche 911 SC       0 mi.
# 1377  1997 Porsche 911 Carrera Cabriolet       0 mi.
#
#                                             Dealer_name Rating Review_count  \
# 0                               CarShop South Brunswick    4.9          24
# 1                                      Champion Porsche    3.6          97
# 2                                         Porsche Plano    4.8       1,078
# 3     Vroom - Get It Delivered Nationwide, Contact-Free    3.7       6,649
# 4                                Gravity Autos Marietta    4.0         130
# ...                                                 ...    ...          ...
# 1373                          Gullwing Motor Cars, Inc.     NA           NA
# 1374                             Beverly Hills Car Club     NA           NA
# 1375                             Beverly Hills Car Club     NA           NA
# 1376                             Beverly Hills Car Club     NA           NA
# 1377                             Beverly Hills Car Club     NA           NA
#
#          Price     0        1        2                  3
# 0      $63,999  2018  Porsche    Macan                GTS
# 1      $71,900  2019  Porsche  Cayenne               Base
# 2     $164,995  2016  Porsche      911            Turbo S
# 3      $33,999  2016  Porsche    Macan                  S
# 4      $49,998  2018  Porsche    Macan               Base
# ...        ...   ...      ...      ...                ...
# 1373  $129,500  1973  Porsche      911                  S
# 1374   $46,500  1969  Porsche      911                  E
# 1375   $54,500  1980  Porsche      911                 SC
# 1376   $59,950  1978  Porsche      911                 SC
# 1377   $58,500  1997  Porsche      911  Carrera Cabriolet
#
# [1378 rows x 10 columns]

# %%
final.to_excel('Porsche_all.xlsx', index=True)

# %% [markdown]
# # Cars.com HONDA

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=all&makes%5B%5D=honda&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %%
response = requests.get(website)
response.status_code
soup = BeautifulSoup(response.content,'html.parser')
results = soup.find_all('div',{'class':'vehicle-card'})

# %%
#Name of car
results[0].find('h2')
results[0].find('h2').get_text() #Just to get only the text

#Km it has run
results[0].find('div',{'class':'mileage'})
results[0].find('div',{'class':'mileage'}).get_text()

#RAting
results[0].find('span',{'class':'sds-rating__count'})
results[0].find('span',{'class':'sds-rating__count'}).get_text()

#Number of Rating
results[0].find('span',{'class':'sds-rating__link sds-button-link'})
results[0].find('span',{'class':'sds-rating__link sds-button-link'}).get_text()

#Price
results[0].find('span',{'class':'primary-price'})
results[0].find('span',{'class':'primary-price'}).get_text()

#Dealer
results[0].find('div',{'class':'dealer-name'})
results[0].find('div',{'class':'dealer-name'}).get_text()
# Out:
# '\nCaspian Auto Group\n'

# %%
#Putting all together
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('NA')
        
     #mileage
    try:
        mileage.append(result.find('div',{'class':'mileage'}).get_text())
    except:
        mileage.append('NA')   
        
     #dealer_name
    try:
        dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
    except:
        dealer_name.append('NA')  
        
     #rating
    try:
        rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
    except:
        rating.append('NA')  
        
    #review Count
    try:
        review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
    except:
        review_count.append('NA') 
        
    #Price
    try:
        price.append(result.find('span',{'class':'primary-price'}).get_text())
    except:
        price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                              Name     mileage  \
# 0          2019 Honda Civic Sport  46,470 mi.
# 1            2019 Honda CR-V EX-L  11,354 mi.
# 2         2019 Honda Odyssey EX-L  29,099 mi.
# 3            2019 Honda CR-V EX-L  19,024 mi.
# 4    2018 Honda Accord Sport 2.0T  15,531 mi.
# 5            2019 Honda CR-V EX-L  59,320 mi.
# 6              2018 Honda CR-V LX  28,126 mi.
# 7             2019 Honda Civic LX  42,650 mi.
# 8            2019 Honda CR-V EX-L  22,690 mi.
# 9         2017 Honda CR-V Touring  27,870 mi.
# 10         2018 Honda Accord EX-L  32,781 mi.
# 11       2020 Honda Odyssey Elite  14,113 mi.
# 12         2018 Honda Accord EX-L  39,193 mi.
# 13  2021 Honda Accord Hybrid EX-L  10,592 mi.
# 14  2021 Honda Accord Hybrid EX-L     867 mi.
# 15     2019 Honda Ridgeline RTL-E  14,623 mi.
# 16           2020 Honda CR-V EX-L  16,203 mi.
# 17             2019 Honda CR-V EX  14,975 mi.
# 18           2018 Honda CR-V EX-L  64,702 mi.
# 19             2019 Honda CR-V EX  15,928 mi.
#
#                                        Dealer_name Rating Review_count  \
# 0                               Caspian Auto Group    4.0          12
# 1                   Frisco Chrysler Dodge Jeep Ram    3.7         432
# 2                     Piazza Honda of Philadelphia    4.7         216
# 3                              Honda of Fort Worth    4.8       2,477
# 4                                AutoSavvy Houston    3.9           7
# 5                                    Huggins Honda    4.8       1,666
# 6                                Russ Darrow Honda    4.7       1,825
# 7                                  Legend Autohaus    4.6          14
# 8                           DallasLeaseReturns.com    4.9       4,037
# 9   EchoPark Automotive Greensboro Delivery Center    1.0           1
# 10                               Merlex Auto Group    3.8         533
# 11                                Gary Force Honda    3.6          30
# 12                   Vann York Chevrolet Buick GMC    4.6         210
# 13                 Pohanka Honda of Fredericksburg    4.8       1,126
# 14                                    Herson's Kia    4.4         188
# 15                       Mungenast St. Louis Honda    4.9       2,592
# 16                     AutoMax Preowned Framingham    4.5       1,191
# 17                               Freeway Chevrolet    4.6       1,317
# 18                              McGrath City Honda    4.6       1,586
# 19                       AutoNation Honda Chandler    4.8       3,275
#
#       Price
# 0   $16,799
# 1   $30,816
# 2   $39,000
# 3   $32,000
# 4   $23,800
# 5   $30,789
# 6   $28,799
# 7   $16,999
# 8   $32,675
# 9   $30,789
# 10  $27,555
# 11  $50,998
# 12  $26,265
# 13  $35,975
# 14  $35,991
# 15  $47,990
# 16  $36,500
# 17  $32,895
# 18  $27,995
# 19  $31,974

# %% [markdown]
# # Pagitation for Honda cars

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range(1,70):
    website = 'https://www.cars.com/shopping/results/?page=' + str(i) + '4&page_size=20&list_price_max=&makes[]=honda&maximum_distance=20&models[]=&stock_type=used&zip='
    
    #requesting permision
    response = requests.get(website)
    
    #soup
    soup = BeautifulSoup(response.content,'html.parser')
    
    #results
    results = soup.find_all('div',{'class':'vehicle-card'})
    
    
    
    
    for result in results:

        #name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('NA')

         #mileage
        try:
            mileage.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            mileage.append('NA')   

         #dealer_name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text())
        except:
            dealer_name.append('NA')  

         #rating
        try:
            rating.append(result.find('span',{'class':'sds-rating__count'}).get_text())
        except:
            rating.append('NA')  

        #review Count
        try:
            review_count.append(result.find('span',{'class':'sds-rating__link sds-button-link'}).get_text())
        except:
            review_count.append('NA') 

        #Price
        try:
            price.append(result.find('span',{'class':'primary-price'}).get_text())
        except:
            price.append('NA')

# %%
car_dealer = pd.DataFrame({'Name':name,'mileage':mileage,'Dealer_name': dealer_name ,'Rating':rating,
                           'Review_count':review_count,'Price':price})

car_dealer['Review_count'] = car_dealer['Review_count'].apply(lambda x:x.strip('reviews)').strip('('))

car_dealer['Dealer_name'] = car_dealer['Dealer_name'].apply(lambda x:x.strip('\n'))

car_dealer
# Out:
#                                         Name      mileage  \
# 0          2012 Honda CR-V EX-L w/Navigation  108,147 mi.
# 1     2019 Honda Pilot EX-L w/Navigation/RES   46,948 mi.
# 2                       2018 Honda CR-V EX-L   37,731 mi.
# 3                2018 Honda Accord EX-L 2.0T   66,448 mi.
# 4                 2019 Honda Ridgeline RTL-E   20,142 mi.
# ...                                      ...          ...
# 1375                   2020 Honda Pilot EX-L   14,294 mi.
# 1376           2019 Honda Accord Hybrid Base   37,405 mi.
# 1377                    2021 Honda CR-V EX-L   11,800 mi.
# 1378                2020 Honda Civic Si Base   22,647 mi.
# 1379                 2019 Honda Odyssey EX-L   74,733 mi.
#
#                                          Dealer_name Rating Review_count  \
# 0                                       Drive Direct    2.3          11
# 1                       Friendly Acura Of Middletown    4.8         261
# 2     EchoPark Automotive Greenville Delivery Center    4.4          19
# 3                              DCH Honda of Temecula    4.8         978
# 4                          Mungenast St. Louis Honda    4.9       2,592
# ...                                              ...    ...          ...
# 1375                     Piazza Honda of Springfield    4.7       2,772
# 1376                   Larry H. Miller Toyota Corona    4.7         920
# 1377                                 Vann York Honda    4.8         825
# 1378                                    Niello Acura    4.6         132
# 1379                               Bettenhausen Fiat    4.8         187
#
#         Price
# 0     $14,994
# 1     $35,560
# 2     $27,499
# 3     $26,053
# 4     $45,990
# ...       ...
# 1375  $40,280
# 1376  $30,986
# 1377  $37,540
# 1378  $32,988
# 1379  $33,489
#
# [1380 rows x 6 columns]

# %%
split = car_dealer['Name'].str.split(' ',n=3, expand = True)
split
# Out:
#          0      1          2                      3
# 0     2012  Honda       CR-V      EX-L w/Navigation
# 1     2019  Honda      Pilot  EX-L w/Navigation/RES
# 2     2018  Honda       CR-V                   EX-L
# 3     2018  Honda     Accord              EX-L 2.0T
# 4     2019  Honda  Ridgeline                  RTL-E
# ...    ...    ...        ...                    ...
# 1375  2020  Honda      Pilot                   EX-L
# 1376  2019  Honda     Accord            Hybrid Base
# 1377  2021  Honda       CR-V                   EX-L
# 1378  2020  Honda      Civic                Si Base
# 1379  2019  Honda    Odyssey                   EX-L
#
# [1380 rows x 4 columns]

# %%
final = pd.concat([car_dealer, split], axis=1, join="inner")
final
# Out:
#                                         Name      mileage  \
# 0          2012 Honda CR-V EX-L w/Navigation  108,147 mi.
# 1     2019 Honda Pilot EX-L w/Navigation/RES   46,948 mi.
# 2                       2018 Honda CR-V EX-L   37,731 mi.
# 3                2018 Honda Accord EX-L 2.0T   66,448 mi.
# 4                 2019 Honda Ridgeline RTL-E   20,142 mi.
# ...                                      ...          ...
# 1375                   2020 Honda Pilot EX-L   14,294 mi.
# 1376           2019 Honda Accord Hybrid Base   37,405 mi.
# 1377                    2021 Honda CR-V EX-L   11,800 mi.
# 1378                2020 Honda Civic Si Base   22,647 mi.
# 1379                 2019 Honda Odyssey EX-L   74,733 mi.
#
#                                          Dealer_name Rating Review_count  \
# 0                                       Drive Direct    2.3          11
# 1                       Friendly Acura Of Middletown    4.8         261
# 2     EchoPark Automotive Greenville Delivery Center    4.4          19
# 3                              DCH Honda of Temecula    4.8         978
# 4                          Mungenast St. Louis Honda    4.9       2,592
# ...                                              ...    ...          ...
# 1375                     Piazza Honda of Springfield    4.7       2,772
# 1376                   Larry H. Miller Toyota Corona    4.7         920
# 1377                                 Vann York Honda    4.8         825
# 1378                                    Niello Acura    4.6         132
# 1379                               Bettenhausen Fiat    4.8         187
#
#         Price     0      1          2                      3
# 0     $14,994  2012  Honda       CR-V      EX-L w/Navigation
# 1     $35,560  2019  Honda      Pilot  EX-L w/Navigation/RES
# 2     $27,499  2018  Honda       CR-V                   EX-L
# 3     $26,053  2018  Honda     Accord              EX-L 2.0T
# 4     $45,990  2019  Honda  Ridgeline                  RTL-E
# ...       ...   ...    ...        ...                    ...
# 1375  $40,280  2020  Honda      Pilot                   EX-L
# 1376  $30,986  2019  Honda     Accord            Hybrid Base
# 1377  $37,540  2021  Honda       CR-V                   EX-L
# 1378  $32,988  2020  Honda      Civic                Si Base
# 1379  $33,489  2019  Honda    Odyssey                   EX-L
#
# [1380 rows x 10 columns]

# %%
final.to_excel('Honda_all.xlsx', index=True)
